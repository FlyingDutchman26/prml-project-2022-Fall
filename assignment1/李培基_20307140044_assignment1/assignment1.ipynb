# %% [markdown]
# # Fudan RPML Assignment1: Machine Learning Meets Fashion

# %% [markdown]
# ![Machine Learning Meets Fashion](./img/ml_meets_fashion.jpg)

# %% [markdown]
# *Your name and Student ID: [李培基], [20307140044]*
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission.*

# %% [markdown]
# In this assignment, you will use what you have learned to tackle some pratical problems. Fashion MNIST dataset[1] is the MNIST-like fashion product database for image classification you will play with this time. It originally consists of a training set of 60000 examples and a test set of 10000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#
# To make this task more realistic, we selected 14600 labeled examples from the training set and did a little processing. You have to do this image classifictaion task with our new dataset.

# %% [markdown]
# You have to impletement several standard classification methods in the './fudanPRML' folder:
# - K-nearest Neighbor (15 points)
# - Softmax (15 points)
# - Neural Network (30 points)
#
# and then do your exploration (30 points).

# %% [markdown]
# You can only use some basic python libraries in your experiment like numpy, paddle(without using the paddle.nn), matplotlib and so on. And please write down the version with them in the './requirements.txt' file.

# %% [markdown]
# ## 1. Setup

# %%
# setup code
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# 当导入了自己写的python模块时，在ipynb文件里import一次之后，即使修改了的python模块，重新运行import其实还是用的之前的python模块
# 因为已经将该模块在第一次导入时存在了内存里，第二次import没效果，这时需要重启kenel才能导入修改过的python模块。
# 此处首先自动加载导入的python模块，保证你每次在ipynb里使用的模块是最新版本，所以在你修改了模块代码之后，不需要重新刷新你的kenel。

import paddle
import numpy as np
from matplotlib import pyplot as plt


paddle.device.get_device()
paddle.set_device(paddle.device.get_device())

np.random.seed(1012)
paddle.seed(1012)

dataset_path = './dataset'
X_train = np.load(dataset_path + '/X_train.npy')
y_train = np.load(dataset_path + '/y_train.npy')
X_test = np.load(dataset_path + '/X_test.npy')
y_test = np.load(dataset_path + '/y_test.npy')

is_shuffle = True
if is_shuffle:
    idx = paddle.randperm(X_train.shape[0])
    X_train = X_train[idx]
    y_train = y_train[idx]
# Out:
# W1106 13:34:00.415654    98 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 8.0, Driver API Version: 11.2, Runtime API Version: 11.2
# W1106 13:34:00.418864    98 device_context.cc:465] device: 0, cuDNN Version: 8.2.

# %% [markdown]
# #### 图片展示

# %%
label_name = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']
# %matplotlib inline
# 可以将matplotlib的图表直接嵌入到Notebook之中，或者使用指定的界面库显示图表
from matplotlib import pyplot as plt

plt.imshow(X_train[0].reshape(28,28))
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2349: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(obj, collections.Iterator):
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2366: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   return list(data) if isinstance(data, collections.MappingView) else data
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/image.py:425: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   a_min = np.asscalar(a_min.astype(scaled_dtype))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/image.py:426: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   a_max = np.asscalar(a_max.astype(scaled_dtype))

# %% [markdown]
# ## 2. Exploratory Data Analysis (5 points)

# %% [markdown]
# Your may have to explore the dataset and do some analysis first.

# %%
import matplotlib
matplotlib.rcParams['font.family']='SimHei'

print('训练集数据类型：',X_train.dtype)
print('训练集中元素最大值/最小值：',np.max(X_train),'/',np.min(X_train))

label_summary = [0 for i in range(10)]
for label in y_train:
    label_summary[label] = label_summary[label] + 1
print('训练集中各类别条目数量:\n',label_summary)
plt.figure(figsize=(7,7))
# plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']  #指定字体为雅黑，解决文字乱码问题
plt.title('Proportion of items in each category in training set')
plt.pie(label_summary,labels=label_name,autopct="%1.1f%%")
plt.show()
print('观察可知存在类别不均衡的问题\n')
plt.figure(figsize=(7,7))
X_train_list = X_train.reshape(-1)
plt.title('Data distribution in training set')
plt.hist(X_train_list)
plt.show()
print('观察可知数据分布不均匀，而且0较多，且值的差异较大，从0-255不等\n')
# Out:
# 训练集数据类型： uint8
# 训练集中元素最大值/最小值： 255 / 0
# 训练集中各类别条目数量:
#  [6000, 4000, 1000, 1000, 1000, 1000, 200, 200, 100, 100]
# 观察可知存在类别不均衡的问题
#
# 观察可知数据分布不均匀，而且0较多，且值的差异较大，从0-255不等
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# ### 3.1 K-nearest Neighbor (15 points)

# %% [markdown]
# #### 实例化KNN分类器

# %%
from fudanPRML.neighbors.k_nearest_neighbor import KNearestNeighbor
clf = KNearestNeighbor()
clf.fit(X_train, y_train)
dists = clf.compute_distances_no_loops(X_test)
print(dists.shape)
# Out:
# (10000, 14600)

# %% [markdown]
# #### 进行5折交叉验证选择最优超参数k的值

# %%
num_folds = 5
k_choices = [1, 3, 4, 5,6,7, 8]

X_train_folds = []
y_train_folds = []
X_train_folds = np.array_split(X_train, num_folds)
y_train_folds = np.array_split(y_train, num_folds)
k_to_accuracies = {}
for k in k_choices:
    acc = []
    for i in range(num_folds):
        X_val_train = np.vstack(X_train_folds[0:i] + X_train_folds[i+1:])
        y_val_train = np.hstack(y_train_folds[0:i] + y_train_folds[i+1:])
        clf.fit(X_val_train,y_val_train)
        y_pred = clf.predict(X_train_folds[i], k)
        num_correct = np.sum(y_pred == y_train_folds[i])
        accuracy = float(num_correct) / len(y_train_folds[i])
        acc.append(accuracy)
        k_to_accuracies[k] = acc


# 打印出计算的精度
for k in sorted(k_to_accuracies):
    for accuracy in k_to_accuracies[k]:
        print('k = %d, accuracy = %f' % (k, accuracy),end = '\t')
    print()
# Out:
# k = 1, accuracy = 0.898288	k = 1, accuracy = 0.901712	k = 1, accuracy = 0.903425	k = 1, accuracy = 0.904795	k = 1, accuracy = 0.903767
# k = 3, accuracy = 0.906849	k = 3, accuracy = 0.912671	k = 3, accuracy = 0.911986	k = 3, accuracy = 0.910616	k = 3, accuracy = 0.904110
# k = 4, accuracy = 0.907877	k = 4, accuracy = 0.917466	k = 4, accuracy = 0.910959	k = 4, accuracy = 0.914384	k = 4, accuracy = 0.912671
# k = 5, accuracy = 0.904452	k = 5, accuracy = 0.920890	k = 5, accuracy = 0.910616	k = 5, accuracy = 0.912671	k = 5, accuracy = 0.911644
# k = 6, accuracy = 0.907877	k = 6, accuracy = 0.920548	k = 6, accuracy = 0.909932	k = 6, accuracy = 0.914726	k = 6, accuracy = 0.913356
# k = 7, accuracy = 0.907192	k = 7, accuracy = 0.917123	k = 7, accuracy = 0.911301	k = 7, accuracy = 0.913356	k = 7, accuracy = 0.909932
# k = 8, accuracy = 0.906849	k = 8, accuracy = 0.915753	k = 8, accuracy = 0.910616	k = 8, accuracy = 0.909247	k = 8, accuracy = 0.911301

# %%
# 绘制原始观察结果
for k in k_choices:
    accuracies = k_to_accuracies[k]
    plt.scatter([k] * len(accuracies), accuracies)

# 用与标准偏差相对应的误差线绘制趋势线
accuracies_mean = np.array([np.mean(v) for k,v in sorted(k_to_accuracies.items())])
accuracies_std = np.array([np.std(v) for k,v in sorted(k_to_accuracies.items())])
plt.errorbar(k_choices, accuracies_mean, yerr=accuracies_std)
plt.title('Cross-validation on k')
plt.xlabel('k')
plt.ylabel('Cross-validation accuracy')
plt.show()

# %% [markdown]
# #### 选择最佳k值，使用全部训练数据训练分类器并测试

# %%
# 根据上述交叉验证结果，为k选择最佳值，使用所有训练数据重新训练分类器，
# 并在测试中对其进行测试数据。
best_k = k_choices[accuracies_mean.argmax()]
print('best_k = ',best_k)
clf = KNearestNeighbor()
clf.fit(X_train, y_train)
y_test_pred = clf.predict(X_test, k=best_k)

# Compute and display the accuracy
num_correct = np.sum(y_test_pred == y_test)
accuracy = float(num_correct) / len(y_test_pred)
print('Got %d / %d correct => accuracy: %f' % (num_correct, len(y_test_pred), accuracy))
# Out:
# best_k =  6
# Got 7733 / 10000 correct => accuracy: 0.773300

# %% [markdown]
# ### 3.2 Softmax (15 points)

# %% [markdown]
# #### 3.2.1 处理数据集，从训练集再次划分出验证集，用于最优模型保存

# %%
# 验证集比例
valid_rate = 0.3

data_num = X_train.shape[0]
train_num = int(data_num*(1 - valid_rate))

# 训练数据类型是uint8，但是paddle居然不支持! 这里分别转为float32和int32
X_train_set = paddle.to_tensor(X_train[:train_num],dtype='float32') 
X_valid_set = paddle.to_tensor(X_train[train_num:],dtype='float32')
y_train_set = paddle.to_tensor(y_train[:train_num],dtype='int32')   
y_valid_set = paddle.to_tensor(y_train[train_num:],dtype='int32')
X_test_set = paddle.to_tensor(X_test,dtype = 'float32')
y_test_set = paddle.to_tensor(y_test,dtype = 'int32')

# %% [markdown]
# #### 3.2.2 定义模型、损失函数、优化器、评价指标、绘图函数、封装好的用于训练测试的Runner类

# %%
from fudanPRML.linear_model.softmax import SoftmaxClassifier
from fudanPRML.linear_model.criterion import MultiCrossEntropyLoss
from fudanPRML.linear_model.optimizer import SimpleBatchGD
from fudanPRML.linear_model.metric import accuracy
from fudanPRML.linear_model.plot import plot
from fudanPRML.linear_model.runner import RunnerV2

# %% [markdown]
# #### 3.2.3 设置参数，实例化模型

# %%
init_lr = 0.01
num_epochs = 1000
log_epochs = 10

model = SoftmaxClassifier(input_dim = 784 ,output_dim = 10)
metric = accuracy
criterion = MultiCrossEntropyLoss()
optimizer = SimpleBatchGD(init_lr=init_lr,model=model)
# 实例化RunnerV2
runner = RunnerV2(model, optimizer, metric, criterion)

# %% [markdown]
# #### 3.2.4 启动训练

# %%
runner.train([X_train_set, y_train_set], [X_valid_set, y_valid_set], num_epochs = num_epochs, log_epochs = log_epochs, save_path="best_model.pdparams")
# Out:
# best accuracy performence has been updated: 0.00000 --> 0.40183
# [Train] epoch: 0, loss: 21.68511962890625, score: 0.05802348256111145
# [Dev] epoch: 0, loss: 13.773063659667969, score: 0.4018264710903168
# best accuracy performence has been updated: 0.40183 --> 0.69132
# best accuracy performence has been updated: 0.69132 --> 0.75160
# best accuracy performence has been updated: 0.75160 --> 0.76872
# [Train] epoch: 10, loss: 5.831787586212158, score: 0.7462817430496216
# [Dev] epoch: 10, loss: 5.31977653503418, score: 0.768721342086792
# best accuracy performence has been updated: 0.76872 --> 0.77785
# [Train] epoch: 20, loss: 5.083637237548828, score: 0.7786691784858704
# [Dev] epoch: 20, loss: 5.800473213195801, score: 0.7468036413192749
# best accuracy performence has been updated: 0.77785 --> 0.80068
# best accuracy performence has been updated: 0.80068 --> 0.81279
# [Train] epoch: 30, loss: 4.990875244140625, score: 0.7827788591384888
# [Dev] epoch: 920, loss: 2.830735683441162, score: 0.8764839768409729
# [Train] epoch: 930, loss: 2.9277405738830566, score: 0.8721134662628174
# [Dev] epoch: 930, loss: 3.441707134246826, score: 0.8495433330535889
# [Train] epoch: 940, loss: 3.1120896339416504, score: 0.8638942241668701
# [Dev] epoch: 940, loss: 3.254392623901367, score: 0.8582191467285156
# [Train] epoch: 950, loss: 2.0645830631256104, score: 0.909686803817749
# [Dev] epoch: 950, loss: 2.925964832305908, score: 0.8716894388198853
# [Train] epoch: 960, loss: 2.244450330734253, score: 0.9016632437705994
# [Dev] epoch: 960, loss: 3.1755731105804443, score: 0.8616438508033752
# [Train] epoch: 970, loss: 2.3007357120513916, score: 0.8992170691490173
# [Dev] epoch: 970, loss: 2.7479209899902344, score: 0.8803651928901672
# [Train] epoch: 980, loss: 8.878734588623047, score: 0.6136986017227173
# [Dev] epoch: 980, loss: 6.581543445587158, score: 0.7134702205657959
# best accuracy performence has been updated: 0.88333 --> 0.88447
# [Train] epoch: 990, loss: 1.9199284315109253, score: 0.9151662588119507
# [Dev] epoch: 990, loss: 2.680341958999634, score: 0.8831048607826233
# best accuracy performence has been updated: 0.88447 --> 0.88470
# [Train] epoch: 999, loss: 1.8875046968460083, score: 0.9172210693359375
# [Dev] epoch: 999, loss: 2.6768386363983154, score: 0.8833333253860474

# %% [markdown]
# #### 3.2.6 绘制图像

# %%
# 绘制训练过程中loss下降图像

plot(runner,fig_name='softmax_classifier.pdf')

# %% [markdown]
# #### 3.2.7 在测试集上评估模型

# %%
# 使用测试集评估模型

# 加载最优模型
runner.load_model('best_model.pdparams')
# 模型评价
score, loss = runner.evaluate([X_test_set, y_test_set])
print(f'[Test Dataset]: accuracy:{score}, loss: {loss}')
# Out:
# [Test Dataset]: accuracy:0.7184998393058777, loss: 6.453721046447754

# %% [markdown]
# #### 3.2.8 一些感受与分析

# %% [markdown]
# ##### 关于使用验证集的问题：
#
# 类别不均衡问题仍然影响很大，在测试集上效果不算太好，使用验证集保存最优参数的方法，事实上也逐渐使得模型拟合在了验证集上
#
# 然而，我们应该注意到，本身测试集类别不均衡，验证集中更可能出现某些类别数量极其小的情况，因此反而效果更差。
#
# ##### 关于优化器和梯度下降过程：
#
# 一开始使用了lr = 0.1 的整批常规梯度下降方法，在训练到接近100轮epoch时，loss出现激增。分析原因，应该是在训练后期学习率过大所致，后续可以采用学习率衰减或者动量的方法

# %% [markdown]
# ### 3.3 Neural Network (30 points)

# %% [markdown]
# #### 3.3.1 数据集构建
# 直接使用 3.2.1 中划分好的数据集，在此不再重复

# %%
# 验证集比例
valid_rate = 0.3

data_num = X_train.shape[0]
train_num = int(data_num*(1 - valid_rate))

# 训练数据类型是uint8，但是paddle居然不支持! 这里分别转为float32和int32
X_train_set = paddle.to_tensor(X_train[:train_num],dtype='float32') 
X_valid_set = paddle.to_tensor(X_train[train_num:],dtype='float32')
y_train_set = paddle.to_tensor(y_train[:train_num],dtype='int32')   
y_valid_set = paddle.to_tensor(y_train[train_num:],dtype='int32')
X_test_set = paddle.to_tensor(X_test,dtype = 'float32')
y_test_set = paddle.to_tensor(y_test,dtype = 'int32')

# %% [markdown]
# #### 3.3.2 定义模型、损失函数、优化器、评价指标、以及封装好的Runner类

# %%
from fudanPRML.neural_network.mlp import Model_MLP_L2
from fudanPRML.neural_network.CrossEntropy import MultiCrossEntropyLoss
from fudanPRML.neural_network.optimizer import BatchGD
from fudanPRML.neural_network.metric import accuracy
from fudanPRML.neural_network.runner import RunnerV2_1

# %% [markdown]
# #### 3.3.3 开始训练

# %%
epoch_num = 1000

model_saved_dir = "model"

# 输入层维度为2
input_size = 784
# 隐藏层维度为5
hidden_size = 256
# 输出层维度为1
output_size = 10

# 定义网络
model = Model_MLP_L2(input_size=input_size, hidden_size=hidden_size, output_size=output_size)

# 损失函数
loss_fn = MultiCrossEntropyLoss(model = model)

# 优化器
learning_rate = 0.1
optimizer = BatchGD(learning_rate, model)

# 评价方法
metric = accuracy

# 实例化RunnerV2_1类，并传入训练配置
runner = RunnerV2_1(model, optimizer, metric, loss_fn)

runner.train([X_train_set, y_train_set], [X_valid_set, y_valid_set], num_epochs=epoch_num, log_epochs=1, save_dir=model_saved_dir)
# Out:
# [Train] epoch: 1000/1000, loss: 0.15044160187244415, score: 0.9544029831886292

# %% [markdown]
# #### 3.3.4 绘制图像

# %%
# 打印训练集和验证集的损失 
from fudanPRML.neural_network.plot import plot
plot(runner,fig_name='nnfigure')

# %% [markdown]
# #### 3.3.5 在测试集上评估模型
#
# 可以看到，同样经过1000轮训练，两层前馈神经网络在测试集上准确率更高了

# %%
# 加载训练好的模型
runner.load_model(model_saved_dir)
# 在测试集上对模型进行评价
score, loss = runner.evaluate([X_test_set, y_test_set])

print("[Test] score/loss: {:.4f}/{:.4f}".format(score, loss))
# Out:
# [Test] score/loss: 0.7474/0.8070

# %% [markdown]
# ### 3.4 Your Exploration (30 points)

# %% [markdown]
# #### 3.4.0 Xavier及Kaiming He 参数初始化
#
# 众所周知，参数的初始化像投胎一样。
#
# 众所周知，投胎的好坏比后天的努力重要的多。
#
# 因此在这里采用了两种初始化方式，Xavier初始化对应着sigmoid等饱和型激活函数，Kaiming He初始化对应着ReLU激活函数。
#
# 膜拜一下何凯明大神，目前主流默认激活函数都是ReLU，而Pytorch对Linear层的默认初始化方式就是Kaiming He初始化。因此，我们采用这种初始化方式。
#
# 能够有效避免ReLU死亡或饱和函数的梯度消失问题

# %%
# 具体见
from fudanPRML.neural_network.Layer.Linear import Linear

# %% [markdown]
# #### 3.4.1 Normalization (归一化)
#
# 事实上我没有一开始就想到这个事情，属于是忘掉了。这是我做了后面一些探索之后发现不对劲才想起这个问题。
#
# 但是后面发现了两个问题：
#
# 1、就算采用了过采样，仍然得不到好的结果
#
# 2、我使用现在最流行的ReLU激活函数替换了之前的sigmoid(Logistic)激活函数，但发生梯度爆炸，接着来一次极其异常的参数更新，整个神经网络基本死亡，正确率预测基本固定在0.1，loss稳定在2.302（这是因为，神经网络就在瞎猜，10个类别瞎猜每十个数据猜中一个，loss就会是2.302这个可怕的数据）
#
# 为了解决这个问题我原来还怀疑是Linear层初始化的问题，故还去搜索资料，使用了Kaming He的初始化方法，仍然不见效果。
#
# 直到最后，回看以前在MNIST数据集上做的实验，才发现，人家先有一个整体的Normalization的过程！而且发现自己的ReLU层的反向传播写错了！
#
# 寄！
#
# 来吧，先给整体数据做一下Normalization吧！ 0到255的值直接扔进去训练确实离谱
#
# 我使用了经典的Standardization方法（又称Z-score）, 转换后分布的参数可能会变，但分布类型不会改变，更不一定就是正态分布(误区)
#
# $$
#
# x = \frac{x - x_{mean}}{std}
#
# $$
#
# 这种方法被广泛应用于对图像的处理中，其优点主要是一般可以收敛更快，且受初始化参数的影响会小一些
#
# 一般这种情况下，就不需要训练那么多轮，需要较少的轮次，loss就会在训练集上收敛
#
# 但这只是对训练过程的优化，对于过拟合，以及样本类别不均衡等问题（导致验证集也类别不均衡！），并没有什么帮助！因此并不会对测试集结果有多少改善。

# %%
import numpy as np
mean_train = np.mean(X_train)
std_train = np.std(X_train)
mean_test = np.mean(X_test)
std_test = np.std(X_test)
X_train = (X_train-mean_train)/std_train
X_test = (X_test - mean_test)/std_test

# 验证集比例
valid_rate = 0.3

data_num = X_train.shape[0]
train_num = int(data_num*(1 - valid_rate))

# 训练数据类型是uint8，但是paddle居然不支持! 这里分别转为float32和int32
X_train_set = paddle.to_tensor(X_train[:train_num],dtype='float32') 
X_valid_set = paddle.to_tensor(X_train[train_num:],dtype='float32')
y_train_set = paddle.to_tensor(y_train[:train_num],dtype='int32')   
y_valid_set = paddle.to_tensor(y_train[train_num:],dtype='int32')
X_test_set = paddle.to_tensor(X_test,dtype = 'float32')
y_test_set = paddle.to_tensor(y_test,dtype = 'int32')

# %% [markdown]
# ##### 我们先使用KNN测试一下效果
# 归一化的处理方式对于KNN这种距离类的学习方法往往效果会好些，可以看到测试集上准确率已经比不做处理有了少许进步
#
# 77.3 -> 78.5% !

# %%
from fudanPRML.neighbors.k_nearest_neighbor import KNearestNeighbor
clf = KNearestNeighbor()
clf.fit(X_train, y_train)
y_test_pred = clf.predict(X_test, k=5)
num_correct = np.sum(y_test_pred == y_test)
accuracy = float(num_correct) / len(y_test_pred)
print('Got %d / %d correct => accuracy: %f' % (num_correct, len(y_test_pred), accuracy))
# Out:
# Got 7805 / 10000 correct => accuracy: 0.780500

# %% [markdown]
# ##### 我们用MLP_L2 来测试一下效果

# %%
from fudanPRML.neural_network.plot import plot
from fudanPRML.neural_network.mlp import Model_MLP_L2
from fudanPRML.neural_network.CrossEntropy import MultiCrossEntropyLoss
from fudanPRML.neural_network.optimizer import BatchGD
from fudanPRML.neural_network.metric import accuracy
from fudanPRML.neural_network.runner import RunnerV2_1,RunnerV3

epoch_num = 1000

model_saved_dir = "model"

# 输入层维度为2
input_size = 784
# 隐藏层维度为5
hidden_size = 256
# 输出层维度为1
output_size = 10

# 定义网络
model = Model_MLP_L2(input_size=input_size, hidden_size=hidden_size, output_size=output_size)

# 这是一个5层神经网络
# model = Model_MLP_L5(input_size=input_size,output_size=output_size)

# 损失函数
loss_fn = MultiCrossEntropyLoss(model = model)

# 优化器
learning_rate = 0.01
optimizer = BatchGD(learning_rate, model)

# 评价方法
metric = accuracy

# 实例化RunnerV2_1类，并传入训练配置
runner = RunnerV2_1(model, optimizer, metric, loss_fn)

runner.train([X_train_set,y_train_set], [X_valid_set, y_valid_set], num_epochs=epoch_num, log_epochs=1, save_dir=model_saved_dir)
plot(runner,fig_name='nnfigure')
# 加载训练好的模型
runner.load_model(model_saved_dir)
# 在测试集上对模型进行评价
score, loss = runner.evaluate([X_test_set, y_test_set])

print("[Test] score/loss: {:.4f}/{:.4f}".format(score, loss))
# Out:
# [Train] epoch: 1000/1000, loss: 0.4645639955997467, score: 0.8561643362045288
# [Test] score/loss: 0.4737/1.4787

# %% [markdown]
# #### 3.4.2 小批量随机梯度下降法
#
# 这种方法同样是用于优化训练的，对于过拟合和类别不均衡，以及最终结果，并没有很大作用。
#
# 然而，使用小批量随机梯度下降法，其在训练过程中带来的改进是极其显著的。往往，又只需更少的epoch就可以使得loss快速收敛！
#
# 随机小批度带来的噪声，往往能够使loss更快的下降，而不是在以全训练集为整批求loss和梯度那种如此光滑的函数面上下降。
#
# 能够有效避开局部最优和鞍点！
#
# 但是这样的方法加入了循环，实际上每轮epoch实际上训练了许多次，每个epoch的速度是变慢了许多。
#
# 但往往需要更少的epoch就可以使loss迅速收敛。
#
# 我们使用paddle提供的dataset，dataloader方法完成这个任务
#
# 同时重新写了一个应用于小批度随机梯度下降的RunnerV3类封装训练过程
#
# 同样在MLP_L2上试验一下
#
# 之前epoch都取为1000，从现在开始取为100
#
# 71% -> 75% !

# %%
import paddle.io as io

class Dataset(io.Dataset):
    def __init__(self,X,y):
        super(Dataset,self).__init__()
        self.X = X
        self.y = y
        self.len = self.y.shape[0]
    def __getitem__(self, idx):
        return self.X[idx],self.y[idx]
    def __len__(self):
        return self.len

# %%
from fudanPRML.neural_network.plot import plot
from fudanPRML.neural_network.mlp import Model_MLP_L2
from fudanPRML.neural_network.CrossEntropy import MultiCrossEntropyLoss
from fudanPRML.neural_network.optimizer import BatchGD
from fudanPRML.neural_network.metric import accuracy
from fudanPRML.neural_network.runner import RunnerV3
from fudanPRML.neural_network.Layer.ReLU import ReLU


batch_size = 64

train_dataset = Dataset(X_train_set,y_train_set)
train_loader = io.DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
epoch_num = 100

model_saved_dir = "model"

# 输入层维度为2
input_size = 784
# 隐藏层维度为5
hidden_size = 256
# 输出层维度为1
output_size = 10

# 定义网络
model = Model_MLP_L2(input_size=input_size, hidden_size=hidden_size, output_size=output_size)

# 损失函数
loss_fn = MultiCrossEntropyLoss(model = model)

# 优化器
learning_rate = 0.01
optimizer = BatchGD(learning_rate, model)

# 评价方法
metric = accuracy

# 实例化RunnerV2_1类，并传入训练配置
runner = RunnerV3(model, optimizer, metric, loss_fn)

runner.train(train_loader, [X_valid_set, y_valid_set], num_epochs=epoch_num, log_epochs=1, save_dir=model_saved_dir)
plot(runner,fig_name='nnfigure')
# 加载训练好的模型
runner.load_model(model_saved_dir)
# 在测试集上对模型进行评价
score, loss = runner.evaluate([X_test_set, y_test_set])

print("[Test] score/loss: {:.4f}/{:.4f}".format(score, loss))
# Out:
# [Evaluate] best accuracy performence has been updated: 0.00000 --> 0.02854
# [Evaluate] best accuracy performence has been updated: 0.02854 --> 0.04703
# [Evaluate] best accuracy performence has been updated: 0.04703 --> 0.11233
# [Evaluate] best accuracy performence has been updated: 0.11233 --> 0.37283
# [Evaluate] best accuracy performence has been updated: 0.37283 --> 0.39886
# [Evaluate] best accuracy performence has been updated: 0.39886 --> 0.39977
# [Evaluate] best accuracy performence has been updated: 0.39977 --> 0.40091
# [Evaluate] best accuracy performence has been updated: 0.40091 --> 0.51164
# [Evaluate] best accuracy performence has been updated: 0.51164 --> 0.55342
# [Evaluate] best accuracy performence has been updated: 0.55342 --> 0.57397
# [Evaluate] best accuracy performence has been updated: 0.57397 --> 0.58242
# [Evaluate] best accuracy performence has been updated: 0.58242 --> 0.60890
# [Evaluate] best accuracy performence has been updated: 0.60890 --> 0.62763
# [Evaluate] best accuracy performence has been updated: 0.62763 --> 0.63767
# [Evaluate] best accuracy performence has been updated: 0.63767 --> 0.64155
# [Evaluate] best accuracy performence has been updated: 0.64155 --> 0.64406
# [Evaluate] best accuracy performence has been updated: 0.64406 --> 0.64680
# [Evaluate] best accuracy performence has been updated: 0.64680 --> 0.64795
# [Evaluate] best accuracy performence has been updated: 0.64795 --> 0.65000
# [Evaluate] best accuracy performence has been updated: 0.65000 --> 0.65023
# [Evaluate] best accuracy performence has been updated: 0.65023 --> 0.65046
# [Evaluate] best accuracy performence has been updated: 0.65046 --> 0.65068
# [Evaluate] best accuracy performence has been updated: 0.65068 --> 0.65114
# [Evaluate] best accuracy performence has been updated: 0.65114 --> 0.65228
# [Evaluate] best accuracy performence has been updated: 0.65228 --> 0.65502
# [Evaluate] best accuracy performence has been updated: 0.65502 --> 0.65753
# [Evaluate] best accuracy performence has been updated: 0.65753 --> 0.65799
# [Evaluate] best accuracy performence has been updated: 0.65799 --> 0.66712
# [Evaluate] best accuracy performence has been updated: 0.66712 --> 0.66735
# [Evaluate] best accuracy performence has been updated: 0.66735 --> 0.67009
# [Evaluate] best accuracy performence has been updated: 0.67009 --> 0.67374
# [Evaluate] best accuracy performence has been updated: 0.67374 --> 0.67808
# [Evaluate] best accuracy performence has been updated: 0.67808 --> 0.68310
# [Evaluate] best accuracy performence has been updated: 0.68310 --> 0.68402
# [Evaluate] best accuracy performence has been updated: 0.68402 --> 0.68562
# [Evaluate] best accuracy performence has been updated: 0.68562 --> 0.68790
# [Evaluate] best accuracy performence has been updated: 0.68790 --> 0.68813
# [Evaluate] best accuracy performence has been updated: 0.68813 --> 0.68927
# [Evaluate] best accuracy performence has been updated: 0.68927 --> 0.69269
# [Evaluate] best accuracy performence has been updated: 0.69269 --> 0.69315
# [Evaluate] best accuracy performence has been updated: 0.69315 --> 0.69566
# [Evaluate] best accuracy performence has been updated: 0.69566 --> 0.69658
# [Evaluate] best accuracy performence has been updated: 0.69658 --> 0.69840
# [Evaluate] best accuracy performence has been updated: 0.69840 --> 0.69909
# [Evaluate] best accuracy performence has been updated: 0.69909 --> 0.70023
# [Evaluate] best accuracy performence has been updated: 0.70023 --> 0.70114
# [Evaluate] best accuracy performence has been updated: 0.70114 --> 0.70320
# [Evaluate] best accuracy performence has been updated: 0.70320 --> 0.70616
# [Evaluate] best accuracy performence has been updated: 0.70616 --> 0.70639
# [Evaluate] best accuracy performence has been updated: 0.70639 --> 0.70822
# [Evaluate] best accuracy performence has been updated: 0.70822 --> 0.71324
# [Evaluate] best accuracy performence has been updated: 0.71324 --> 0.71438
# [Evaluate] best accuracy performence has been updated: 0.71438 --> 0.71644
# [Evaluate] best accuracy performence has been updated: 0.71644 --> 0.71872
# [Evaluate] best accuracy performence has been updated: 0.71872 --> 0.72603
# [Evaluate] best accuracy performence has been updated: 0.72603 --> 0.73128
# [Evaluate] best accuracy performence has been updated: 0.73128 --> 0.74087
# [Evaluate] best accuracy performence has been updated: 0.74087 --> 0.74269
# [Evaluate] best accuracy performence has been updated: 0.74269 --> 0.74384
# [Evaluate] best accuracy performence has been updated: 0.74384 --> 0.74498
# [Evaluate] best accuracy performence has been updated: 0.74498 --> 0.74680
# [Evaluate] best accuracy performence has been updated: 0.74680 --> 0.74863
# [Evaluate] best accuracy performence has been updated: 0.74863 --> 0.74863
# [Evaluate] best accuracy performence has been updated: 0.74863 --> 0.74931
# [Evaluate] best accuracy performence has been updated: 0.74931 --> 0.75137
# [Train] epoch: 1/100, loss: 1.1474188566207886, score: 0.6656161222606898
# [Evaluate] best accuracy performence has been updated: 0.75137 --> 0.75365
# [Evaluate] best accuracy performence has been updated: 0.75365 --> 0.75525
# [Evaluate] best accuracy performence has been updated: 0.75525 --> 0.75776
# [Evaluate] best accuracy performence has been updated: 0.75776 --> 0.75822
# [Evaluate] best accuracy performence has been updated: 0.75822 --> 0.76142
# [Evaluate] best accuracy performence has been updated: 0.76142 --> 0.76804
# [Evaluate] best accuracy performence has been updated: 0.76804 --> 0.77009
# [Evaluate] best accuracy performence has been updated: 0.77009 --> 0.77100
# [Evaluate] best accuracy performence has been updated: 0.77100 --> 0.77123
# [Evaluate] best accuracy performence has been updated: 0.77123 --> 0.77146
# [Evaluate] best accuracy performence has been updated: 0.77146 --> 0.77215
# [Evaluate] best accuracy performence has been updated: 0.77215 --> 0.77306
# [Evaluate] best accuracy performence has been updated: 0.77306 --> 0.77534
# [Evaluate] best accuracy performence has been updated: 0.77534 --> 0.77671
# [Evaluate] best accuracy performence has been updated: 0.77671 --> 0.77717
# [Evaluate] best accuracy performence has been updated: 0.77717 --> 0.77922
# [Train] epoch: 97/100, loss: 0.23547211289405823, score: 0.927405895292759
# [Train] epoch: 98/100, loss: 0.23483328521251678, score: 0.927503551542759
# [Train] epoch: 99/100, loss: 0.2342030555009842, score: 0.927503551542759
# [Train] epoch: 100/100, loss: 0.23357200622558594, score: 0.9276012077927589
# [Test] score/loss: 0.7500/0.7515

# %% [markdown]
# #### 3.4.3 使用带有Momentum（动量）的优化器
#
# 前期可以加速，后期可以提高稳定性
#
# 实现于 fudanPRML.neural_network.optimizer 的 SGD 中
#
# 明显获得了更好的效果，更快的收敛速度！
#
# 可以看到其“稳定器”的作用，loss后期震荡幅度越来越小了！
#
# 75% -> 79.7% !

# %%
from fudanPRML.neural_network.plot import plot
from fudanPRML.neural_network.mlp import Model_MLP_L2
from fudanPRML.neural_network.CrossEntropy import MultiCrossEntropyLoss
from fudanPRML.neural_network.optimizer import SGD
from fudanPRML.neural_network.metric import accuracy
from fudanPRML.neural_network.runner import RunnerV2_1,RunnerV3
from fudanPRML.neural_network.Layer.ReLU import ReLU

batch_size = 64

train_dataset = Dataset(X_train_set,y_train_set)
train_loader = io.DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
epoch_num = 100

model_saved_dir = "model"

# 输入层维度为2
input_size = 784
# 隐藏层维度为5
hidden_size = 256
# 输出层维度为1
output_size = 10

# 定义网络
model = Model_MLP_L2(input_size=input_size, hidden_size=hidden_size, output_size=output_size)


# 损失函数
loss_fn = MultiCrossEntropyLoss(model = model)

# 优化器
learning_rate = 0.01
optimizer = SGD(learning_rate, model,rho=0.9)

# 评价方法
metric = accuracy

# 实例化RunnerV2_1类，并传入训练配置
runner = RunnerV3(model, optimizer, metric, loss_fn)

runner.train(train_loader, [X_valid_set, y_valid_set], num_epochs=epoch_num, log_epochs=1, save_dir=model_saved_dir)
plot(runner,fig_name='nnfigure')
# 加载训练好的模型
runner.load_model(model_saved_dir)
# 在测试集上对模型进行评价
score, loss = runner.evaluate([X_test_set, y_test_set])

print("[Test] score/loss: {:.4f}/{:.4f}".format(score, loss))
# Out:
# [Evaluate] best accuracy performence has been updated: 0.00000 --> 0.37534
# [Evaluate] best accuracy performence has been updated: 0.37534 --> 0.39977
# [Evaluate] best accuracy performence has been updated: 0.39977 --> 0.40023
# [Evaluate] best accuracy performence has been updated: 0.40023 --> 0.57740
# [Evaluate] best accuracy performence has been updated: 0.57740 --> 0.63699
# [Evaluate] best accuracy performence has been updated: 0.63699 --> 0.64384
# [Evaluate] best accuracy performence has been updated: 0.64384 --> 0.66324
# [Evaluate] best accuracy performence has been updated: 0.66324 --> 0.69977
# [Evaluate] best accuracy performence has been updated: 0.69977 --> 0.72352
# [Evaluate] best accuracy performence has been updated: 0.72352 --> 0.73904
# [Evaluate] best accuracy performence has been updated: 0.73904 --> 0.74543
# [Evaluate] best accuracy performence has been updated: 0.74543 --> 0.75160
# [Evaluate] best accuracy performence has been updated: 0.75160 --> 0.75297
# [Evaluate] best accuracy performence has been updated: 0.75297 --> 0.75685
# [Evaluate] best accuracy performence has been updated: 0.75685 --> 0.75936
# [Evaluate] best accuracy performence has been updated: 0.75936 --> 0.76119
# [Evaluate] best accuracy performence has been updated: 0.76119 --> 0.76119
# [Evaluate] best accuracy performence has been updated: 0.76119 --> 0.76484
# [Evaluate] best accuracy performence has been updated: 0.76484 --> 0.76849
# [Evaluate] best accuracy performence has been updated: 0.76849 --> 0.77420
# [Evaluate] best accuracy performence has been updated: 0.77420 --> 0.77968
# [Evaluate] best accuracy performence has been updated: 0.77968 --> 0.78516
# [Evaluate] best accuracy performence has been updated: 0.78516 --> 0.79132
# [Evaluate] best accuracy performence has been updated: 0.79132 --> 0.79772
# [Evaluate] best accuracy performence has been updated: 0.79772 --> 0.80068
# [Evaluate] best accuracy performence has been updated: 0.80068 --> 0.80571
# [Evaluate] best accuracy performence has been updated: 0.80571 --> 0.80913
# [Evaluate] best accuracy performence has been updated: 0.80913 --> 0.81530
# [Evaluate] best accuracy performence has been updated: 0.81530 --> 0.82078
# #### 3.4.4 更多层的前馈神经网络架构
# 本任务中默认要求完成一个MLP_L2，即一个两层的前馈神经网络。
#
# 而一般来说，在达到同样的测试效果时，深层网络会比浅层网络需要更少的参数量。
#
# 因此，我定义了一个5层的前馈神经网络，其架构为：
#
# (784,512),(512,256),(256,128),(128,64),(64,10)
#
# 使用此网络，我在MNIST手写数字识别数据集上训练，可以达到95%的准确率，因此在此网络中同样进行尝试。
#
# 后续的探索，有时会使用这个MLP_L5的架构
#
# 然而，这个网络虽然能力远远比两层MLP强，但是参数也远远超过两层MLP，因此需要更多的训练轮次才可以达到收敛！
#
# 事实上可以发现，有时候网络结构不是影响结果的问题，问题是训练数据的不一致性。即使后续通过算法解决类别不均衡问题，也很难与测试数据达到同一分布

# %%
from fudanPRML.neural_network.mlp import Model_MLP_L5

# %% [markdown]
# #### 3.4.5 解决类别不均衡问题
# 类别不均衡的问题会对数据训练过程产生很大影响，在多分类问题中又称为“长尾”问题，进行预测类别时，分类器将有预测训练数据中数量最多的类别的趋势，这可以在训练中达到极高的准确率。
#
# 然而，我们往往关心的是分类器在测试数据集中，对任何一类数据预测的表现，即使它的数量很少
#
# 最常见的方法，是对数据集直接进行处理，这其中，一般有 过采样(重采样)，欠采样 两种方法，因采样存在丢弃训练数据的情况，容易造成欠拟合，因此又以过采样应用为多。
#
# 常用方法有SMOTE，ADASYN，SMOTE_borderline等等
#
# 我们使用了imbalanced-learn库帮助完成这个任务
#
# 使用pip install -U imbalanced-learn
#
# 或者 conda install imbalanced-learn 安装
#
# 使用conda安装需要先添加一个国内的对condaforge的镜像源

# %% [markdown]
# ##### 3.4.2.1 ROS 简单随机过采样 (Naive random over-sampling)
#  The most naive strategy is to generate new samples by randomly sampling with replacement the current available samples.
#
#  这种方法极其容易造成过拟合，我们不过多实验，仅仅在KNN上试验一下效果

# %% [markdown]
# ##### 进行ROS过采样及数据处理

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
ros = RandomOverSampler(random_state=0)
X_train_resampled,y_train_resampled = ros.fit_resample(X_train,y_train)

# %% [markdown]
# ##### ROS + KNN
#
# 可以看到，虽然就是重复采样，但是效果已经比之前有了很大提升！
#
# 78.5% -> 80.07% !

# %%
from fudanPRML.neighbors.k_nearest_neighbor import KNearestNeighbor
clf = KNearestNeighbor()
clf.fit(X_train_resampled, y_train_resampled)
y_test_pred = clf.predict(X_test, k=5)
num_correct = np.sum(y_test_pred == y_test)
accuracy = float(num_correct) / len(y_test_pred)
print('Got %d / %d correct => accuracy: %f' % (num_correct, len(y_test_pred), accuracy))
# Out:
# Got 8007 / 10000 correct => accuracy: 0.800700

# %% [markdown]
# #####  SMOTE算法
# SMOTE是基于KNN的一种随机插值算法，其不再是简单的重复采样，而是使用了在临近点之间随机差值的方法

# %% [markdown]
# ##### SMOTE过采样及数据处理

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
X_train_resampled, y_train_resampled = SMOTE().fit_resample(X_train, y_train)
print('当前各类别数量',sorted(Counter(y_train_resampled).items()))

# 此处必须重新打乱！过采样采集的数据不是很均匀！
idx = paddle.randperm(X_train_resampled.shape[0])
X_train_resampled = X_train_resampled[idx]
y_train_resampled = y_train_resampled[idx]

# 验证集比例
valid_rate = 0.2
data_num = X_train_resampled.shape[0]
train_num = int(data_num*(1 - valid_rate))

# 训练数据类型是uint8，但是paddle居然不支持! 这里分别转为float32和int32
X_train_set = paddle.to_tensor(X_train_resampled[:train_num],dtype='float32') 
X_valid_set = paddle.to_tensor(X_train_resampled[train_num:],dtype='float32')
y_train_set = paddle.to_tensor(y_train_resampled[:train_num],dtype='int32')   
y_valid_set = paddle.to_tensor(y_train_resampled[train_num:],dtype='int32')
X_test_set = paddle.to_tensor(X_test,dtype = 'float32')
y_test_set = paddle.to_tensor(y_test,dtype = 'int32')
# Out:
# 当前各类别数量 [(0, 6000), (1, 6000), (2, 6000), (3, 6000), (4, 6000), (5, 6000), (6, 6000), (7, 6000), (8, 6000), (9, 6000)]

# %% [markdown]
# ##### SMOTE + KNN
# 可以看到，使用SMOTE后，KNN的效果比ROS的重复采样，明显又有了进步！
#
# 80.07% -> 81.95% !
#
# 81.95% 是本次使用KNN的最好结果！

# %%
from fudanPRML.neighbors.k_nearest_neighbor import KNearestNeighbor
clf = KNearestNeighbor()
clf.fit(X_train_resampled, y_train_resampled)
y_test_pred = clf.predict(X_test, k=5)
num_correct = np.sum(y_test_pred == y_test)
accuracy = float(num_correct) / len(y_test_pred)
print('Got %d / %d correct => accuracy: %f' % (num_correct, len(y_test_pred), accuracy))
# Out:
# Got 8195 / 10000 correct => accuracy: 0.819500

# %% [markdown]
# ##### SMOTE + MLP_L2
#
# 在测试集上正确率明显提升！
# 79.7 % -> 82.25%

# %%
from fudanPRML.neural_network.plot import plot
from fudanPRML.neural_network.mlp import Model_MLP_L2
from fudanPRML.neural_network.CrossEntropy import MultiCrossEntropyLoss
from fudanPRML.neural_network.optimizer import SGD
from fudanPRML.neural_network.metric import accuracy
from fudanPRML.neural_network.runner import RunnerV3


batch_size = 64

train_dataset = Dataset(X_train_set,y_train_set)
train_loader = io.DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

epoch_num = 100

model_saved_dir = "model"

# 输入层维度为2
input_size = 784
# 隐藏层维度为5
hidden_size = 256
# 输出层维度为1
output_size = 10

# 定义网络
model = Model_MLP_L2(input_size=input_size, hidden_size=hidden_size, output_size=output_size)

# 损失函数
loss_fn = MultiCrossEntropyLoss(model = model)

# 优化器
learning_rate = 0.01
optimizer = SGD(learning_rate, model,rho=0.9)

# 评价方法
metric = accuracy

# 实例化RunnerV2_1类，并传入训练配置
runner = RunnerV3(model, optimizer, metric, loss_fn)

runner.train(train_loader, [X_valid_set, y_valid_set], num_epochs=epoch_num, log_epochs=1, save_dir=model_saved_dir)
plot(runner,fig_name='nnfigure')
# 加载训练好的模型
runner.load_model(model_saved_dir)
# 在测试集上对模型进行评价
score, loss = runner.evaluate([X_test_set, y_test_set])

print("[Test] score/loss: {:.4f}/{:.4f}".format(score, loss))
# Out:
# [Evaluate] best accuracy performence has been updated: 0.00000 --> 0.08225
# [Evaluate] best accuracy performence has been updated: 0.08225 --> 0.15983
# [Evaluate] best accuracy performence has been updated: 0.15983 --> 0.25017
# [Evaluate] best accuracy performence has been updated: 0.25017 --> 0.27917
# [Evaluate] best accuracy performence has been updated: 0.27917 --> 0.30775
# [Evaluate] best accuracy performence has been updated: 0.30775 --> 0.35292
# [Evaluate] best accuracy performence has been updated: 0.35292 --> 0.37408
# [Evaluate] best accuracy performence has been updated: 0.37408 --> 0.42367
# [Evaluate] best accuracy performence has been updated: 0.42367 --> 0.45867
# [Evaluate] best accuracy performence has been updated: 0.45867 --> 0.48367
# [Evaluate] best accuracy performence has been updated: 0.48367 --> 0.49375
# [Evaluate] best accuracy performence has been updated: 0.49375 --> 0.49692
# [Evaluate] best accuracy performence has been updated: 0.49692 --> 0.51883
# [Evaluate] best accuracy performence has been updated: 0.51883 --> 0.53050
# [Evaluate] best accuracy performence has been updated: 0.53050 --> 0.56142
# [Evaluate] best accuracy performence has been updated: 0.56142 --> 0.61167
# [Evaluate] best accuracy performence has been updated: 0.61167 --> 0.66608
# [Evaluate] best accuracy performence has been updated: 0.66608 --> 0.67883
# [Evaluate] best accuracy performence has been updated: 0.67883 --> 0.68650
# [Evaluate] best accuracy performence has been updated: 0.68650 --> 0.69750
# [Evaluate] best accuracy performence has been updated: 0.69750 --> 0.70158
# [Evaluate] best accuracy performence has been updated: 0.70158 --> 0.70475
# [Evaluate] best accuracy performence has been updated: 0.70475 --> 0.71192
# [Evaluate] best accuracy performence has been updated: 0.71192 --> 0.72167
# [Evaluate] best accuracy performence has been updated: 0.72167 --> 0.72417
# [Evaluate] best accuracy performence has been updated: 0.72417 --> 0.72600
# [Evaluate] best accuracy performence has been updated: 0.72600 --> 0.73125
# [Evaluate] best accuracy performence has been updated: 0.73125 --> 0.73508
# [Evaluate] best accuracy performence has been updated: 0.73508 --> 0.73992
# [Evaluate] best accuracy performence has been updated: 0.73992 --> 0.74217
# [Evaluate] best accuracy performence has been updated: 0.74217 --> 0.74583
# [Evaluate] best accuracy performence has been updated: 0.74583 --> 0.74883
# [Evaluate] best accuracy performence has been updated: 0.74883 --> 0.75192
# [Evaluate] best accuracy performence has been updated: 0.75192 --> 0.75567
# [Evaluate] best accuracy performence has been updated: 0.75567 --> 0.76258
# [Evaluate] best accuracy performence has been updated: 0.76258 --> 0.76875
# [Evaluate] best accuracy performence has been updated: 0.76875 --> 0.76967
# [Evaluate] best accuracy performence has been updated: 0.76967 --> 0.77083
# [Evaluate] best accuracy performence has been updated: 0.77083 --> 0.77225
# [Evaluate] best accuracy performence has been updated: 0.77225 --> 0.77317
# [Evaluate] best accuracy performence has been updated: 0.77317 --> 0.77433
# [Evaluate] best accuracy performence has been updated: 0.77433 --> 0.77458
# [Evaluate] best accuracy performence has been updated: 0.77458 --> 0.77867
# [Evaluate] best accuracy performence has been updated: 0.77867 --> 0.78283
# [Evaluate] best accuracy performence has been updated: 0.78283 --> 0.78700
# [Evaluate] best accuracy performence has been updated: 0.78700 --> 0.78933
# [Evaluate] best accuracy performence has been updated: 0.78933 --> 0.79017
# [Evaluate] best accuracy performence has been updated: 0.79017 --> 0.79450
# [Evaluate] best accuracy performence has been updated: 0.79450 --> 0.79833
# [Evaluate] best accuracy performence has been updated: 0.79833 --> 0.79883
# [Evaluate] best accuracy performence has been updated: 0.79883 --> 0.80125
# [Evaluate] best accuracy performence has been updated: 0.80125 --> 0.80242
# [Evaluate] best accuracy performence has been updated: 0.80242 --> 0.80442
# [Evaluate] best accuracy performence has been updated: 0.80442 --> 0.80658
# [Evaluate] best accuracy performence has been updated: 0.80658 --> 0.80808
# [Evaluate] best accuracy performence has been updated: 0.80808 --> 0.80992
# [Evaluate] best accuracy performence has been updated: 0.80992 --> 0.81258
# [Evaluate] best accuracy performence has been updated: 0.81258 --> 0.81392
# [Evaluate] best accuracy performence has been updated: 0.81392 --> 0.81658
# [Evaluate] best accuracy performence has been updated: 0.81658 --> 0.81775
# [Evaluate] best accuracy performence has been updated: 0.81775 --> 0.81867
# [Evaluate] best accuracy performence has been updated: 0.81867 --> 0.81875
# [Evaluate] best accuracy performence has been updated: 0.81875 --> 0.81992
# [Train] epoch: 6/100, loss: 0.15859068930149078, score: 0.9520833333333333
# [Evaluate] best accuracy performence has been updated: 0.95192 --> 0.95208
# [Evaluate] best accuracy performence has been updated: 0.95208 --> 0.95208
# [Evaluate] best accuracy performence has been updated: 0.95208 --> 0.95242
# [Evaluate] best accuracy performence has been updated: 0.95242 --> 0.95267
# [Evaluate] best accuracy performence has been updated: 0.95267 --> 0.95292
# [Evaluate] best accuracy performence has been updated: 0.95292 --> 0.95300
# [Evaluate] best accuracy performence has been updated: 0.95300 --> 0.95342
# [Evaluate] best accuracy performence has been updated: 0.95342 --> 0.95358
# [Evaluate] best accuracy performence has been updated: 0.95358 --> 0.95358
# [Evaluate] best accuracy performence has been updated: 0.95358 --> 0.95417
# [Evaluate] best accuracy performence has been updated: 0.95417 --> 0.95425
# [Evaluate] best accuracy performence has been updated: 0.95425 --> 0.95442
# [Evaluate] best accuracy performence has been updated: 0.95442 --> 0.95492
# [Evaluate] best accuracy performence has been updated: 0.95492 --> 0.95550
# [Evaluate] best accuracy performence has been updated: 0.95550 --> 0.95550
# [Evaluate] best accuracy performence has been updated: 0.95550 --> 0.95575
# [Evaluate] best accuracy performence has been updated: 0.95575 --> 0.95600
# [Evaluate] best accuracy performence has been updated: 0.95600 --> 0.95617
# [Train] epoch: 7/100, loss: 0.14325445890426636, score: 0.9570833333333333
# [Evaluate] best accuracy performence has been updated: 0.95617 --> 0.95625
# [Evaluate] best accuracy performence has been updated: 0.95625 --> 0.95633
# [Evaluate] best accuracy performence has been updated: 0.95633 --> 0.95633
# [Evaluate] best accuracy performence has been updated: 0.95633 --> 0.95642
# [Evaluate] best accuracy performence has been updated: 0.95642 --> 0.95658
# [Evaluate] best accuracy performence has been updated: 0.95658 --> 0.95667
# [Evaluate] best accuracy performence has been updated: 0.95667 --> 0.95708
# [Evaluate] best accuracy performence has been updated: 0.95708 --> 0.95717
# [Evaluate] best accuracy performence has been updated: 0.95717 --> 0.95775
# [Evaluate] best accuracy performence has been updated: 0.95775 --> 0.95833
# [Evaluate] best accuracy performence has been updated: 0.95833 --> 0.95858
# [Evaluate] best accuracy performence has been updated: 0.95858 --> 0.95875
# [Evaluate] best accuracy performence has been updated: 0.95875 --> 0.95892
# [Evaluate] best accuracy performence has been updated: 0.95892 --> 0.95925
# [Evaluate] best accuracy performence has been updated: 0.95925 --> 0.96000
# [Evaluate] best accuracy performence has been updated: 0.96000 --> 0.96008
# [Train] epoch: 8/100, loss: 0.1303708851337433, score: 0.9613125
# [Evaluate] best accuracy performence has been updated: 0.96008 --> 0.96033
# [Evaluate] best accuracy performence has been updated: 0.96033 --> 0.96042
# [Evaluate] best accuracy performence has been updated: 0.96042 --> 0.96083
# [Evaluate] best accuracy performence has been updated: 0.96083 --> 0.96117
# [Evaluate] best accuracy performence has been updated: 0.96117 --> 0.96142
# [Evaluate] best accuracy performence has been updated: 0.96142 --> 0.96158
# [Evaluate] best accuracy performence has been updated: 0.96158 --> 0.96167
# [Evaluate] best accuracy performence has been updated: 0.96167 --> 0.96283
# [Evaluate] best accuracy performence has been updated: 0.96283 --> 0.96292
# [Evaluate] best accuracy performence has been updated: 0.96292 --> 0.96300
# [Evaluate] best accuracy performence has been updated: 0.96300 --> 0.96408
# [Evaluate] best accuracy performence has been updated: 0.96408 --> 0.96425
# [Train] epoch: 9/100, loss: 0.11933949589729309, score: 0.9648958333333333
# [Evaluate] best accuracy performence has been updated: 0.96425 --> 0.96442
# [Evaluate] best accuracy performence has been updated: 0.96442 --> 0.96483
# [Evaluate] best accuracy performence has been updated: 0.96483 --> 0.96525
# [Evaluate] best accuracy performence has been updated: 0.96525 --> 0.96567
# [Evaluate] best accuracy performence has been updated: 0.96567 --> 0.96583
# [Evaluate] best accuracy performence has been updated: 0.96583 --> 0.96600
# [Evaluate] best accuracy performence has been updated: 0.96600 --> 0.96650
# [Evaluate] best accuracy performence has been updated: 0.96650 --> 0.96717
# [Train] epoch: 10/100, loss: 0.10976610332727432, score: 0.9679166666666666
# [Evaluate] best accuracy performence has been updated: 0.96717 --> 0.96725
# [Evaluate] best accuracy performence has been updated: 0.96725 --> 0.96792
# [Evaluate] best accuracy performence has been updated: 0.96792 --> 0.96842
# [Evaluate] best accuracy performence has been updated: 0.96842 --> 0.96858
# [Evaluate] best accuracy performence has been updated: 0.96858 --> 0.96867
# [Evaluate] best accuracy performence has been updated: 0.96867 --> 0.96900
# [Train] epoch: 11/100, loss: 0.10135950893163681, score: 0.9710208333333333
# [Evaluate] best accuracy performence has been updated: 0.96900 --> 0.96908
# [Evaluate] best accuracy performence has been updated: 0.96908 --> 0.96917
# [Evaluate] best accuracy performence has been updated: 0.96917 --> 0.96950
# [Evaluate] best accuracy performence has been updated: 0.96950 --> 0.96950
# [Evaluate] best accuracy performence has been updated: 0.96950 --> 0.96992
# [Evaluate] best accuracy performence has been updated: 0.96992 --> 0.97025
# [Evaluate] best accuracy performence has been updated: 0.97025 --> 0.97058
# [Evaluate] best accuracy performence has been updated: 0.97058 --> 0.97075
# [Train] epoch: 12/100, loss: 0.09390085935592651, score: 0.9735416666666666
# [Evaluate] best accuracy performence has been updated: 0.97075 --> 0.97108
# [Evaluate] best accuracy performence has been updated: 0.97108 --> 0.97117
# [Evaluate] best accuracy performence has been updated: 0.97117 --> 0.97133
# [Evaluate] best accuracy performence has been updated: 0.97133 --> 0.97142
# [Evaluate] best accuracy performence has been updated: 0.97142 --> 0.97183
# [Evaluate] best accuracy performence has been updated: 0.97183 --> 0.97225
# [Evaluate] best accuracy performence has been updated: 0.97225 --> 0.97233
# [Evaluate] best accuracy performence has been updated: 0.97233 --> 0.97300
# [Train] epoch: 13/100, loss: 0.08722907304763794, score: 0.9759375
# [Evaluate] best accuracy performence has been updated: 0.97300 --> 0.97317
# [Evaluate] best accuracy performence has been updated: 0.97317 --> 0.97325
# [Evaluate] best accuracy performence has been updated: 0.97325 --> 0.97325
# [Evaluate] best accuracy performence has been updated: 0.97325 --> 0.97358
# [Evaluate] best accuracy performence has been updated: 0.97358 --> 0.97367
# [Evaluate] best accuracy performence has been updated: 0.97367 --> 0.97408
# [Evaluate] best accuracy performence has been updated: 0.97408 --> 0.97433
# [Evaluate] best accuracy performence has been updated: 0.97433 --> 0.97433
# [Train] epoch: 14/100, loss: 0.08122017979621887, score: 0.977875
# [Evaluate] best accuracy performence has been updated: 0.97433 --> 0.97442
# [Evaluate] best accuracy performence has been updated: 0.97442 --> 0.97475
# [Evaluate] best accuracy performence has been updated: 0.97475 --> 0.97500
# [Evaluate] best accuracy performence has been updated: 0.97500 --> 0.97500
# [Evaluate] best accuracy performence has been updated: 0.97500 --> 0.97508
# [Evaluate] best accuracy performence has been updated: 0.97508 --> 0.97567
# [Evaluate] best accuracy performence has been updated: 0.97567 --> 0.97575
# [Evaluate] best accuracy performence has been updated: 0.97575 --> 0.97583
# [Evaluate] best accuracy performence has been updated: 0.97583 --> 0.97633
# [Train] epoch: 15/100, loss: 0.07577904313802719, score: 0.9796458333333333
# [Evaluate] best accuracy performence has been updated: 0.97633 --> 0.97642
# [Evaluate] best accuracy performence has been updated: 0.97642 --> 0.97667
# [Evaluate] best accuracy performence has been updated: 0.97667 --> 0.97675
# [Evaluate] best accuracy performence has been updated: 0.97675 --> 0.97683
# [Evaluate] best accuracy performence has been updated: 0.97683 --> 0.97700
# [Evaluate] best accuracy performence has been updated: 0.97700 --> 0.97750
# [Evaluate] best accuracy performence has been updated: 0.97750 --> 0.97800
# [Train] epoch: 16/100, loss: 0.07083411514759064, score: 0.9815
# [Evaluate] best accuracy performence has been updated: 0.97800 --> 0.97808
# [Evaluate] best accuracy performence has been updated: 0.97808 --> 0.97842
# [Evaluate] best accuracy performence has been updated: 0.97842 --> 0.97858
# [Evaluate] best accuracy performence has been updated: 0.97858 --> 0.97883
# [Train] epoch: 17/100, loss: 0.06631801277399063, score: 0.9827708333333334
# [Evaluate] best accuracy performence has been updated: 0.97883 --> 0.97908
# [Evaluate] best accuracy performence has been updated: 0.97908 --> 0.97925
# [Evaluate] best accuracy performence has been updated: 0.97925 --> 0.97942
# [Evaluate] best accuracy performence has been updated: 0.97942 --> 0.97950
# [Evaluate] best accuracy performence has been updated: 0.97950 --> 0.97958
# [Evaluate] best accuracy performence has been updated: 0.97958 --> 0.98000
# [Train] epoch: 18/100, loss: 0.06217681244015694, score: 0.9839375
# [Evaluate] best accuracy performence has been updated: 0.98000 --> 0.98017
# [Evaluate] best accuracy performence has been updated: 0.98017 --> 0.98025
# [Evaluate] best accuracy performence has been updated: 0.98025 --> 0.98025
# [Evaluate] best accuracy performence has been updated: 0.98025 --> 0.98033
# [Evaluate] best accuracy performence has been updated: 0.98033 --> 0.98042
# [Evaluate] best accuracy performence has been updated: 0.98042 --> 0.98075
# [Evaluate] best accuracy performence has been updated: 0.98075 --> 0.98083
# [Evaluate] best accuracy performence has been updated: 0.98083 --> 0.98100
# [Train] epoch: 19/100, loss: 0.05836665257811546, score: 0.98475
# [Evaluate] best accuracy performence has been updated: 0.98100 --> 0.98125
# [Evaluate] best accuracy performence has been updated: 0.98125 --> 0.98133
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# [Test] score/loss: 0.8225/1.0546

# %% [markdown]
# #### 3.4.6 不同激活函数的影响
# 之前默认使用了Logistic激活函数，然而在多层前馈神经网络训练中，可能出现梯度消失的问题，因此不太适用于MLP_L5
#
# 接下来将尝试ReLU，Leaky_ReLU等更广泛使用的激活函数。
#
# ReLU能有效避免梯度消失的问题，然而在学习率过大时，在一次不恰当地参数更新后，很可能出现死亡ReLU问题，直接造成某个神经元地死亡。因此有时引入Leaky_ReLU是有必要的
#
# 但是实际应用中，ReLU往往用的更多

# %% [markdown]
# ##### SMOTE + ReLU + MLP_L2
#
# 结果也有少量提升，但不是很明显。毕竟网络较浅，而且不是卷积网络。
#
# 但观察可以发现，使用ReLU可以在训练集上迅速拟合，居然早早就在训练集上达到了100%的准确率。显然是有过拟合的。
#
# 即使在验证集上也有很高准确率，但是测试集和训练集的分布是不一样的。这才是最大问题
#
# 82.25% -> 82.40% !

# %%
from fudanPRML.neural_network.mlp import Model_MLP_L2
from fudanPRML.neural_network.CrossEntropy import MultiCrossEntropyLoss
from fudanPRML.neural_network.optimizer import SGD
from fudanPRML.neural_network.metric import accuracy
from fudanPRML.neural_network.runner import RunnerV3
from fudanPRML.neural_network.plot import plot
from fudanPRML.neural_network.Layer.ReLU import ReLU
from fudanPRML.neural_network.Layer.Logistic import Logistic


batch_size = 64

train_dataset = Dataset(X_train_set,y_train_set)
train_loader = io.DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

epoch_num = 100

model_saved_dir = "model"

# 输入层维度为2
input_size = 784
# 隐藏层维度为5
hidden_size = 256
# 输出层维度为1
output_size = 10

# 定义网络
model = Model_MLP_L2(input_size=input_size, hidden_size=hidden_size, output_size=output_size,act_fn=ReLU)

# 损失函数
loss_fn = MultiCrossEntropyLoss(model = model)

# 优化器
learning_rate = 0.01
optimizer = SGD(learning_rate, model)

# 评价方法
metric = accuracy

# 实例化RunnerV2_1类，并传入训练配置
runner = RunnerV3(model, optimizer, metric, loss_fn,act_fn = ReLU)

runner.train(train_loader, [X_valid_set, y_valid_set], num_epochs=epoch_num, log_epochs=1, save_dir=model_saved_dir)
# 打印训练集和验证集的损失 
plot(runner,fig_name='nnfigure')
# 加载训练好的模型
runner.load_model(model_saved_dir)
# 在测试集上对模型进行评价
score, loss = runner.evaluate([X_test_set, y_test_set])
print("[Test] accuravy/loss: {:.4f}/{:.4f}".format(score, loss))
# Out:
# [Evaluate] best accuracy performence has been updated: 0.00000 --> 0.18025
# [Evaluate] best accuracy performence has been updated: 0.18025 --> 0.35233
# [Evaluate] best accuracy performence has been updated: 0.35233 --> 0.44508
# [Evaluate] best accuracy performence has been updated: 0.44508 --> 0.48792
# [Evaluate] best accuracy performence has been updated: 0.48792 --> 0.51617
# [Evaluate] best accuracy performence has been updated: 0.51617 --> 0.56800
# [Evaluate] best accuracy performence has been updated: 0.56800 --> 0.61142
# [Evaluate] best accuracy performence has been updated: 0.61142 --> 0.63092
# [Evaluate] best accuracy performence has been updated: 0.63092 --> 0.64917
# [Evaluate] best accuracy performence has been updated: 0.64917 --> 0.65625
# [Evaluate] best accuracy performence has been updated: 0.65625 --> 0.66800
# [Evaluate] best accuracy performence has been updated: 0.66800 --> 0.68433
# [Evaluate] best accuracy performence has been updated: 0.68433 --> 0.71533
# [Evaluate] best accuracy performence has been updated: 0.71533 --> 0.71967
# [Evaluate] best accuracy performence has been updated: 0.71967 --> 0.73125
# [Evaluate] best accuracy performence has been updated: 0.73125 --> 0.75592
# [Evaluate] best accuracy performence has been updated: 0.75592 --> 0.76492
# [Evaluate] best accuracy performence has been updated: 0.76492 --> 0.77067
# [Evaluate] best accuracy performence has been updated: 0.77067 --> 0.78925
# [Evaluate] best accuracy performence has been updated: 0.78925 --> 0.80183
# [Evaluate] best accuracy performence has been updated: 0.80183 --> 0.80342
# [Evaluate] best accuracy performence has been updated: 0.80342 --> 0.81275
# [Evaluate] best accuracy performence has been updated: 0.81275 --> 0.81717
# [Evaluate] best accuracy performence has been updated: 0.81717 --> 0.82708
# [Evaluate] best accuracy performence has been updated: 0.82708 --> 0.83167
# [Evaluate] best accuracy performence has been updated: 0.83167 --> 0.83458
# [Evaluate] best accuracy performence has been updated: 0.83458 --> 0.83708
# [Evaluate] best accuracy performence has been updated: 0.83708 --> 0.84058
# [Evaluate] best accuracy performence has been updated: 0.84058 --> 0.84683
# [Evaluate] best accuracy performence has been updated: 0.84683 --> 0.84842
# [Evaluate] best accuracy performence has been updated: 0.84842 --> 0.85017
# [Evaluate] best accuracy performence has been updated: 0.85017 --> 0.85200
# [Evaluate] best accuracy performence has been updated: 0.85200 --> 0.86467
# [Evaluate] best accuracy performence has been updated: 0.86467 --> 0.87175
# [Evaluate] best accuracy performence has been updated: 0.87175 --> 0.87733
# [Evaluate] best accuracy performence has been updated: 0.87733 --> 0.87975
# [Evaluate] best accuracy performence has been updated: 0.87975 --> 0.88283
# [Evaluate] best accuracy performence has been updated: 0.88283 --> 0.88408
# [Evaluate] best accuracy performence has been updated: 0.88408 --> 0.88725
# [Evaluate] best accuracy performence has been updated: 0.88725 --> 0.89133
# [Evaluate] best accuracy performence has been updated: 0.89133 --> 0.89308
# [Evaluate] best accuracy performence has been updated: 0.89308 --> 0.89333
# [Evaluate] best accuracy performence has been updated: 0.89333 --> 0.89375
# [Evaluate] best accuracy performence has been updated: 0.89375 --> 0.89383
# [Evaluate] best accuracy performence has been updated: 0.89383 --> 0.89458
# [Evaluate] best accuracy performence has been updated: 0.89458 --> 0.89558
# [Evaluate] best accuracy performence has been updated: 0.89558 --> 0.89717
# [Evaluate] best accuracy performence has been updated: 0.89717 --> 0.89967
# [Evaluate] best accuracy performence has been updated: 0.89967 --> 0.90092
# [Evaluate] best accuracy performence has been updated: 0.90092 --> 0.90133
# [Evaluate] best accuracy performence has been updated: 0.90133 --> 0.90158
# [Evaluate] best accuracy performence has been updated: 0.90158 --> 0.90317
# [Evaluate] best accuracy performence has been updated: 0.90317 --> 0.90667
# [Evaluate] best accuracy performence has been updated: 0.90667 --> 0.90833
# [Evaluate] best accuracy performence has been updated: 0.90833 --> 0.91025
# [Evaluate] best accuracy performence has been updated: 0.91025 --> 0.91433
# [Evaluate] best accuracy performence has been updated: 0.91433 --> 0.91583
# [Evaluate] best accuracy performence has been updated: 0.91583 --> 0.91767
# [Evaluate] best accuracy performence has been updated: 0.91767 --> 0.92008
# [Evaluate] best accuracy performence has been updated: 0.92008 --> 0.92025
# [Evaluate] best accuracy performence has been updated: 0.92025 --> 0.92092
# [Evaluate] best accuracy performence has been updated: 0.92092 --> 0.92133
# [Evaluate] best accuracy performence has been updated: 0.92133 --> 0.92442
# [Evaluate] best accuracy performence has been updated: 0.92442 --> 0.92533
# [Evaluate] best accuracy performence has been updated: 0.92533 --> 0.92667
# [Evaluate] best accuracy performence has been updated: 0.92667 --> 0.92967
# [Evaluate] best accuracy performence has been updated: 0.96233 --> 0.96242
# [Evaluate] best accuracy performence has been updated: 0.96242 --> 0.96325
# [Evaluate] best accuracy performence has been updated: 0.96325 --> 0.96333
# [Evaluate] best accuracy performence has been updated: 0.96333 --> 0.96408
# [Evaluate] best accuracy performence has been updated: 0.96408 --> 0.96442
# [Evaluate] best accuracy performence has been updated: 0.96442 --> 0.96467
# [Evaluate] best accuracy performence has been updated: 0.96467 --> 0.96483
# [Evaluate] best accuracy performence has been updated: 0.96483 --> 0.96667
# [Evaluate] best accuracy performence has been updated: 0.96667 --> 0.96758
# [Evaluate] best accuracy performence has been updated: 0.96758 --> 0.96842
# [Evaluate] best accuracy performence has been updated: 0.96842 --> 0.96950
# [Evaluate] best accuracy performence has been updated: 0.96950 --> 0.96958
# [Evaluate] best accuracy performence has been updated: 0.96958 --> 0.97017
# [Evaluate] best accuracy performence has been updated: 0.97017 --> 0.97025
# [Evaluate] best accuracy performence has been updated: 0.97025 --> 0.97033
# [Evaluate] best accuracy performence has been updated: 0.97033 --> 0.97083
# [Evaluate] best accuracy performence has been updated: 0.97083 --> 0.97125
# [Evaluate] best accuracy performence has been updated: 0.97125 --> 0.97133
# [Train] epoch: 3/100, loss: 0.10039284080266953, score: 0.9681458333333334
# [Evaluate] best accuracy performence has been updated: 0.97133 --> 0.97175
# [Evaluate] best accuracy performence has been updated: 0.97175 --> 0.97258
# [Evaluate] best accuracy performence has been updated: 0.97258 --> 0.97492
# [Evaluate] best accuracy performence has been updated: 0.97492 --> 0.97500
# [Evaluate] best accuracy performence has been updated: 0.97500 --> 0.97567
# [Evaluate] best accuracy performence has been updated: 0.97567 --> 0.97650
# [Evaluate] best accuracy performence has been updated: 0.97650 --> 0.97667
# [Evaluate] best accuracy performence has been updated: 0.97667 --> 0.97683
# [Train] epoch: 4/100, loss: 0.07792375236749649, score: 0.9756041666666667
# [Evaluate] best accuracy performence has been updated: 0.97683 --> 0.97708
# [Evaluate] best accuracy performence has been updated: 0.97708 --> 0.97742
# [Evaluate] best accuracy performence has been updated: 0.97742 --> 0.97775
# [Evaluate] best accuracy performence has been updated: 0.97775 --> 0.97883
# [Evaluate] best accuracy performence has been updated: 0.97883 --> 0.97917
# [Evaluate] best accuracy performence has been updated: 0.97917 --> 0.97933
# [Evaluate] best accuracy performence has been updated: 0.97933 --> 0.97942
# [Evaluate] best accuracy performence has been updated: 0.97942 --> 0.98033
# [Evaluate] best accuracy performence has been updated: 0.98033 --> 0.98133
# [Train] epoch: 5/100, loss: 0.06293215602636337, score: 0.980625
# [Evaluate] best accuracy performence has been updated: 0.98133 --> 0.98142
# [Evaluate] best accuracy performence has been updated: 0.98142 --> 0.98200
# [Evaluate] best accuracy performence has been updated: 0.98200 --> 0.98250
# [Evaluate] best accuracy performence has been updated: 0.98250 --> 0.98283
# [Evaluate] best accuracy performence has been updated: 0.98283 --> 0.98317
# [Evaluate] best accuracy performence has been updated: 0.98317 --> 0.98325
# [Evaluate] best accuracy performence has been updated: 0.98325 --> 0.98433
score: 1.0
# [Evaluate] best accuracy performence has been updated: 0.99383 --> 0.99392
# [Train] epoch: 91/100, loss: 0.00028161585214547813, score: 1.0
# [Train] epoch: 92/100, loss: 0.00027764958213083446, score: 1.0
# [Train] epoch: 93/100, loss: 0.000274014106253162, score: 1.0
# [Train] epoch: 94/100, loss: 0.00027040476561523974, score: 1.0
# [Train] epoch: 95/100, loss: 0.00026685502962209284, score: 1.0
# [Train] epoch: 96/100, loss: 0.0002634701959323138, score: 1.0
# [Train] epoch: 97/100, loss: 0.0002599701110739261, score: 1.0
# [Train] epoch: 98/100, loss: 0.0002567184856161475, score: 1.0
# [Train] epoch: 99/100, loss: 0.0002535198873374611, score: 1.0
# [Train] epoch: 100/100, loss: 0.00025040697073563933, score: 1.0
# [Test] accuravy/loss: 0.8240/1.4705

# %% [markdown]
# ##### SMOTE + ReLU + MLP_L5 + Momentum + SGD
#
# 这比之前使用两层前馈网络的结果又有了少量提升！
#
# 82.40% -> 82.64%!

# %%
from fudanPRML.neural_network.mlp import Model_MLP_L5
from fudanPRML.neural_network.CrossEntropy import MultiCrossEntropyLoss
from fudanPRML.neural_network.optimizer import SGD
from fudanPRML.neural_network.metric import accuracy
from fudanPRML.neural_network.runner import RunnerV3
from fudanPRML.neural_network.plot import plot
from fudanPRML.neural_network.Layer.ReLU import ReLU
from fudanPRML.neural_network.Layer.Logistic import Logistic

epoch_num = 100
batch_size = 64

train_dataset = Dataset(X_train_set,y_train_set)
train_loader = io.DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

model_saved_dir = "model"

# 输入层维度为2
input_size = 784
# 隐藏层维度为5
hidden_size = 256
# 输出层维度为1
output_size = 10

# 定义网络
model = Model_MLP_L5(input_size=input_size,output_size=output_size,act_fn=ReLU)

# 损失函数
loss_fn = MultiCrossEntropyLoss(model = model)

# 优化器
learning_rate = 0.01
optimizer = SGD(learning_rate, model,rho = 0.9)

# 评价方法
metric = accuracy

# 实例化RunnerV2_1类，并传入训练配置
runner = RunnerV3(model, optimizer, metric, loss_fn,act_fn = ReLU)

runner.train(train_loader, [X_valid_set, y_valid_set], num_epochs=epoch_num, log_epochs=1, save_dir=model_saved_dir)
# 打印训练集和验证集的损失 
plot(runner,fig_name='nnfigure')
# 加载训练好的模型
runner.load_model(model_saved_dir)
# 在测试集上对模型进行评价
score, loss = runner.evaluate([X_test_set, y_test_set])
print("[Test] accuravy/loss: {:.4f}/{:.4f}".format(score, loss))
# Out:
# [Evaluate] best accuracy performence has been updated: 0.00000 --> 0.13742
# [Evaluate] best accuracy performence has been updated: 0.13742 --> 0.25717
# [Evaluate] best accuracy performence has been updated: 0.25717 --> 0.33575
# [Evaluate] best accuracy performence has been updated: 0.33575 --> 0.42792
# [Evaluate] best accuracy performence has been updated: 0.42792 --> 0.51008
# [Evaluate] best accuracy performence has been updated: 0.51008 --> 0.57067
# [Evaluate] best accuracy performence has been updated: 0.57067 --> 0.58950
# [Evaluate] best accuracy performence has been updated: 0.58950 --> 0.60775
# [Evaluate] best accuracy performence has been updated: 0.60775 --> 0.63533
# [Evaluate] best accuracy performence has been updated: 0.63533 --> 0.64125
# [Evaluate] best accuracy performence has been updated: 0.64125 --> 0.64692
# [Evaluate] best accuracy performence has been updated: 0.64692 --> 0.67850
# [Evaluate] best accuracy performence has been updated: 0.67850 --> 0.68442
# [Evaluate] best accuracy performence has been updated: 0.68442 --> 0.70850
# [Evaluate] best accuracy performence has been updated: 0.70850 --> 0.72958
# [Evaluate] best accuracy performence has been updated: 0.72958 --> 0.73017
# [Evaluate] best accuracy performence has been updated: 0.73017 --> 0.73983
# [Evaluate] best accuracy performence has been updated: 0.73983 --> 0.74758
# [Evaluate] best accuracy performence has been updated: 0.74758 --> 0.75300
# [Evaluate] best accuracy performence has been updated: 0.75300 --> 0.76225
# [Evaluate] best accuracy performence has been updated: 0.76225 --> 0.76683
# [Evaluate] best accuracy performence has been updated: 0.76683 --> 0.78683
# [Evaluate] best accuracy performence has been updated: 0.78683 --> 0.78917
# [Evaluate] best accuracy performence has been updated: 0.78917 --> 0.80583
# [Evaluate] best accuracy performence has been updated: 0.80583 --> 0.81650
# [Evaluate] best accuracy performence has been updated: 0.81650 --> 0.81725
# [Evaluate] best accuracy performence has been updated: 0.81725 --> 0.82467
# [Evaluate] best accuracy performence has been updated: 0.82467 --> 0.83200
# [Evaluate] best accuracy performence has been updated: 0.83200 --> 0.83242
# [Evaluate] best accuracy performence has been updated: 0.83242 --> 0.83758
# [Evaluate] best accuracy performence has been updated: 0.83758 --> 0.83983
# [Evaluate] best accuracy performence has been updated: 0.83983 --> 0.84333
# [Evaluate] best accuracy performence has been updated: 0.84333 --> 0.84550
# [Evaluate] best accuracy performence has been updated: 0.84550 --> 0.84767
# [Evaluate] best accuracy performence has been updated: 0.84767 --> 0.84958
# [Evaluate] best accuracy performence has been updated: 0.84958 --> 0.85633
# [Evaluate] best accuracy performence has been updated: 0.85633 --> 0.85742
# [Evaluate] best accuracy performence has been updated: 0.85742 --> 0.85842
# [Evaluate] best accuracy performence has been updated: 0.85842 --> 0.86175
# [Evaluate] best accuracy performence has been updated: 0.86175 --> 0.86350
# [Evaluate] best accuracy performence has been updated: 0.86350 --> 0.86992
# [Evaluate] best accuracy performence has been updated: 0.86992 --> 0.87775
# [Evaluate] best accuracy performence has been updated: 0.87775 --> 0.88383
# [Evaluate] best accuracy performence has been updated: 0.88383 --> 0.88592
# [Evaluate] best accuracy performence has been updated: 0.88592 --> 0.88850
# [Evaluate] best accuracy performence has been updated: 0.88850 --> 0.88992
# [Evaluate] best accuracy performence has been updated: 0.88992 --> 0.89400
# [Evaluate] best accuracy performence has been updated: 0.89400 --> 0.89733
# [Evaluate] best accuracy performence has been updated: 0.89733 --> 0.89733
# [Evaluate] best accuracy performence has been updated: 0.89733 --> 0.90142
# [Evaluate] best accuracy performence has been updated: 0.90142 --> 0.90483
# [Evaluate] best accuracy performence has been updated: 0.90483 --> 0.90633
# [Evaluate] best accuracy performence has been updated: 0.90633 --> 0.90708
# [Evaluate] best accuracy performence has been updated: 0.90708 --> 0.90958
# [Evaluate] best accuracy performence has been updated: 0.90958 --> 0.91317
# [Evaluate] best accuracy performence has been updated: 0.91317 --> 0.91433
# [Evaluate] best accuracy performence has been updated: 0.91433 --> 0.92358
# [Evaluate] best accuracy performence has been updated: 0.92358 --> 0.92483
# [Evaluate] best accuracy performence has been updated: 0.92483 --> 0.92733
# [Evaluate] best accuracy performence has been updated: 0.92733 --> 0.92808
# [Evaluate] best accuracy performence has been updated: 0.92808 --> 0.93000
# [Evaluate] best accuracy performence has been updated: 0.93000 --> 0.93142
# [Evaluate] best accuracy performence has been updated: 0.93142 --> 0.93533
# [Evaluate] best accuracy performence has been updated: 0.93533 --> 0.93800
# [Evaluate] best accuracy performence has been updated: 0.93800 --> 0.94000
# [Evaluate] best accuracy performence has been updated: 0.94000 --> 0.94242
# [Evaluate] best accuracy performence has been updated: 0.94242 --> 0.94467
# [Evaluate] best accuracy performence has been updated: 0.94467 --> 0.94475
# [Evaluate] best accuracy performence has been updated: 0.94475 --> 0.94733
# [Evaluate] best accuracy performence has been updated: 0.94733 --> 0.94742
# [Evaluate] best accuracy performence has been updated: 0.94742 --> 0.94875
# [Evaluate] best accuracy performence has been updated: 0.94875 --> 0.94892
# [Evaluate] best accuracy performence has been updated: 0.94892 --> 0.95075
# [Train] epoch: 1/100, loss: 0.3013395369052887, score: 0.8948333333333334
# [Evaluate] best accuracy performence has been updated: 0.95075 --> 0.95175
# [Evaluate] best accuracy performence has been updated: 0.95175 --> 0.95458
# [Evaluate] best accuracy performence has been updated: 0.95458 --> 0.95483
# [Evaluate] best accuracy performence has been updated: 0.95483 --> 0.95583
# [Evaluate] best accuracy performence has been updated: 0.95583 --> 0.95658
# [Evaluate] best accuracy performence has been updated: 0.95658 --> 0.95792
# [Evaluate] best accuracy performence has been updated: 0.95792 --> 0.95800
# [Evaluate] best accuracy performence has been updated: 0.95800 --> 0.95983
# [Evaluate] best accuracy performence has been updated: 0.95983 --> 0.96250
# [Evaluate] best accuracy performence has been updated: 0.96250 --> 0.96283
# [Evaluate] best accuracy performence has been updated: 0.96283 --> 0.96475
# [Evaluate] best accuracy performence has been updated: 0.96475 --> 0.96492
# [Evaluate] best accuracy performence has been updated: 0.96492 --> 0.96617
# [Evaluate] best accuracy performence has been updated: 0.96617 --> 0.96667
# [Evaluate] best accuracy performence has been updated: 0.96667 --> 0.96800
# [Evaluate] best accuracy performence has been updated: 0.96800 --> 0.96858
# [Train] epoch: 2/100, loss: 0.12237289547920227, score: 0.9575416666666666
# [Evaluate] best accuracy performence has been updated: 0.96858 --> 0.96883
# [Evaluate] best accuracy performence has been updated: 0.96883 --> 0.96992
# [Evaluate] best accuracy performence has been updated: 0.96992 --> 0.97133
# [Evaluate] best accuracy performence has been updated: 0.97133 --> 0.97208
# [Evaluate] best accuracy performence has been updated: 0.97208 --> 0.97408
# [Evaluate] best accuracy performence has been updated: 0.97408 --> 0.97425
# [Evaluate] best accuracy performence has been updated: 0.97425 --> 0.97442
# [Evaluate] best accuracy performence has been updated: 0.97442 --> 0.97517
# [Evaluate] best accuracy performence has been updated: 0.97517 --> 0.97558
# [Evaluate] best accuracy performence has been updated: 0.97558 --> 0.97658
# [Train] epoch: 3/100, loss: 0.0914635881781578, score: 0.9683958333333333
# [Evaluate] best accuracy performence has been updated: 0.97658 --> 0.97717
# [Evaluate] best accuracy performence has been updated: 0.97717 --> 0.97750
# [Evaluate] best accuracy performence has been updated: 0.97750 --> 0.97817
# [Evaluate] best accuracy performence has been updated: 0.97817 --> 0.97958
# [Evaluate] best accuracy performence has been updated: 0.97958 --> 0.97992
# [Evaluate] best accuracy performence has been updated: 0.97992 --> 0.98033
# [Train] epoch: 69/100, loss: 6.2727553995500784e-06, score: 1.0
# [Train] epoch: 70/100, loss: 6.154996754048625e-06, score: 1.0
# [Train] epoch: 71/100, loss: 6.045554982847534e-06, score: 1.0
# [Train] epoch: 72/100, loss: 5.940451956121251e-06, score: 1.0
# [Train] epoch: 73/100, loss: 5.8397799875820056e-06, score: 1.0
# [Train] epoch: 74/100, loss: 5.741578661400126e-06, score: 1.0
# [Train] epoch: 75/100, loss: 5.646556473948294e-06, score: 1.0
# [Train] epoch: 76/100, loss: 5.553160917770583e-06, score: 1.0
# [Train] epoch: 77/100, loss: 5.4629517762805335e-06, score: 1.0
# [Train] epoch: 78/100, loss: 5.377536126616178e-06, score: 1.0
# [Train] epoch: 79/100, loss: 5.293448793963762e-06, score: 1.0
# [Train] epoch: 80/100, loss: 5.217107627686346e-06, score: 1.0
# [Train] epoch: 81/100, loss: 5.1372671805438586e-06, score: 1.0
# [Train] epoch: 82/100, loss: 5.058129772805842e-06, score: 1.0
# [Train] epoch: 83/100, loss: 4.986144631402567e-06, score: 1.0
# [Train] epoch: 84/100, loss: 4.91498394694645e-06, score: 1.0
# [Train] epoch: 85/100, loss: 4.843629994866205e-06, score: 1.0
# [Train] epoch: 86/100, loss: 4.7770290620974265e-06, score: 1.0
# [Train] epoch: 87/100, loss: 4.710979737865273e-06, score: 1.0
# [Train] epoch: 88/100, loss: 4.6463037506327964e-06, score: 1.0
# [Train] epoch: 89/100, loss: 4.5851343202230055e-06, score: 1.0
# [Train] epoch: 90/100, loss: 4.5245337787491735e-06, score: 1.0
# [Train] epoch: 91/100, loss: 4.46365538664395e-06, score: 1.0
# [Train] epoch: 92/100, loss: 4.405540494190063e-06, score: 1.0
# [Train] epoch: 93/100, loss: 4.3526615627342835e-06, score: 1.0
# [Train] epoch: 94/100, loss: 4.296409315429628e-06, score: 1.0
# [Train] epoch: 95/100, loss: 4.243433522788109e-06, score: 1.0
# [Train] epoch: 96/100, loss: 4.188458206044743e-06, score: 1.0
# [Train] epoch: 97/100, loss: 4.13928682974074e-06, score: 1.0
# [Train] epoch: 98/100, loss: 4.090033598913578e-06, score: 1.0
# [Train] epoch: 99/100, loss: 4.042764430778334e-06, score: 1.0
# [Train] epoch: 100/100, loss: 3.992664460383821e-06, score: 1.0
# [Test] accuravy/loss: 0.8264/2.2734

# %% [markdown]
# #### 3.4.7 Dropout 层
#
# Dropout层在前馈神经网络中应用广泛，可以有效避免过拟合
#
# 我定义了一个Dropout层进行试验，其正反向传播方法与ReLU基本类似。
#
# 我在Layer中实现了Dropout.py 重新定义了一个Model_MLP_Dropout_L5，在第二层输出和第四层激活函数的输出后，加入了p = 0.2和 0.5 的 Dropout层，进行实验。
#
# 这次把所有能用的都用上了！
#
# 本次采用 Kaiming He初始化 + SMOTE过采样 + 五层MLP(ReLU) + Momentum优化器 + Dropout层 + 随机小批量梯度下降 的组合
#
# 82.64% -> 82.86%
#
# 82.86% 为本次使用前馈神经网络达到的最好结果！

# %%
from fudanPRML.neural_network.mlp import Model_MLP_Dropout_L5
from fudanPRML.neural_network.CrossEntropy import MultiCrossEntropyLoss
from fudanPRML.neural_network.optimizer import SGD
from fudanPRML.neural_network.metric import accuracy
from fudanPRML.neural_network.runner import RunnerV3
from fudanPRML.neural_network.plot import plot
from fudanPRML.neural_network.Layer.ReLU import ReLU
from fudanPRML.neural_network.Layer.Logistic import Logistic

epoch_num = 100
batch_size = 64

train_dataset = Dataset(X_train_set,y_train_set)
train_loader = io.DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

model_saved_dir = "model"

# 输入层维度为2
input_size = 784
# 隐藏层维度为5
hidden_size = 256
# 输出层维度为1
output_size = 10

# 定义网络
model = Model_MLP_L5(input_size=input_size,output_size=output_size,act_fn=ReLU)

# 损失函数
loss_fn = MultiCrossEntropyLoss(model = model)

# 优化器
learning_rate = 0.01
optimizer = SGD(learning_rate, model,rho = 0.9)

# 评价方法
metric = accuracy

# 实例化RunnerV2_1类，并传入训练配置
runner = RunnerV3(model, optimizer, metric, loss_fn,act_fn = ReLU)

runner.train(train_loader, [X_valid_set, y_valid_set], num_epochs=epoch_num, log_epochs=1, save_dir=model_saved_dir)
# 打印训练集和验证集的损失 
plot(runner,fig_name='nnfigure')
# 加载训练好的模型
runner.load_model(model_saved_dir)
# 在测试集上对模型进行评价
score, loss = runner.evaluate([X_test_set, y_test_set])
print("[Test] accuravy/loss: {:.4f}/{:.4f}".format(score, loss))
# Out:
# [Evaluate] best accuracy performence has been updated: 0.00000 --> 0.08167
# [Evaluate] best accuracy performence has been updated: 0.08167 --> 0.24542
# [Evaluate] best accuracy performence has been updated: 0.24542 --> 0.41383
# [Evaluate] best accuracy performence has been updated: 0.41383 --> 0.43367
# [Evaluate] best accuracy performence has been updated: 0.43367 --> 0.60217
# [Evaluate] best accuracy performence has been updated: 0.60217 --> 0.62450
# [Evaluate] best accuracy performence has been updated: 0.62450 --> 0.63167
# [Evaluate] best accuracy performence has been updated: 0.63167 --> 0.65967
# [Evaluate] best accuracy performence has been updated: 0.65967 --> 0.71017
# [Evaluate] best accuracy performence has been updated: 0.71017 --> 0.71408
# [Evaluate] best accuracy performence has been updated: 0.71408 --> 0.71417
# [Evaluate] best accuracy performence has been updated: 0.71417 --> 0.73342
# [Evaluate] best accuracy performence has been updated: 0.73342 --> 0.73875
# [Evaluate] best accuracy performence has been updated: 0.73875 --> 0.75975
# [Evaluate] best accuracy performence has been updated: 0.75975 --> 0.78242
# [Evaluate] best accuracy performence has been updated: 0.78242 --> 0.78400
# [Evaluate] best accuracy performence has been updated: 0.78400 --> 0.79292
# [Evaluate] best accuracy performence has been updated: 0.79292 --> 0.80450
# [Evaluate] best accuracy performence has been updated: 0.80450 --> 0.82025
# [Evaluate] best accuracy performence has been updated: 0.82025 --> 0.82200
# [Evaluate] best accuracy performence has been updated: 0.82200 --> 0.82333
# [Evaluate] best accuracy performence has been updated: 0.82333 --> 0.83600
# [Evaluate] best accuracy performence has been updated: 0.83600 --> 0.84342
# [Evaluate] best accuracy performence has been updated: 0.84342 --> 0.84933
# [Evaluate] best accuracy performence has been updated: 0.95500 --> 0.95800
# [Evaluate] best accuracy performence has been updated: 0.95800 --> 0.95867
# [Evaluate] best accuracy performence has been updated: 0.95867 --> 0.95917
# [Evaluate] best accuracy performence has been updated: 0.95917 --> 0.95992
# [Evaluate] best accuracy performence has been updated: 0.95992 --> 0.96125
# [Evaluate] best accuracy performence has been updated: 0.96125 --> 0.96142
# [Evaluate] best accuracy performence has been updated: 0.96142 --> 0.96233
# [Evaluate] best accuracy performence has been updated: 0.96233 --> 0.96300
# [Evaluate] best accuracy performence has been updated: 0.96300 --> 0.96367
# [Evaluate] best accuracy performence has been updated: 0.96367 --> 0.96417
# [Evaluate] best accuracy performence has been updated: 0.96417 --> 0.96467
# [Evaluate] best accuracy performence has been updated: 0.96467 --> 0.96550
# [Evaluate] best accuracy performence has been updated: 0.96550 --> 0.96642
# [Evaluate] best accuracy performence has been updated: 0.96642 --> 0.96650
# [Evaluate] best accuracy performence has been updated: 0.96650 --> 0.96800
# [Evaluate] best accuracy performence has been updated: 0.96800 --> 0.96825
# [Evaluate] best accuracy performence has been updated: 0.96825 --> 0.96908
# [Train] epoch: 2/100, loss: 0.12151317298412323, score: 0.9579166666666666
# [Evaluate] best accuracy performence has been updated: 0.96908 --> 0.97025
# [Evaluate] best accuracy performence has been updated: 0.97025 --> 0.97058
# [Evaluate] best accuracy performence has been updated: 0.97058 --> 0.97075
# [Evaluate] best accuracy performence has been updated: 0.97075 --> 0.97167
# [Evaluate] best accuracy performence has been updated: 0.97167 --> 0.97242
# [Evaluate] best accuracy performence has been updated: 0.97242 --> 0.97283
# [Evaluate] best accuracy performence has been updated: 0.97283 --> 0.97350
# [Evaluate] best accuracy performence has been updated: 0.97350 --> 0.97425
# [Evaluate] best accuracy performence has been updated: 0.97425 --> 0.97508
# [Evaluate] best accuracy performence has been updated: 0.97508 --> 0.97608
# [Evaluate] best accuracy performence has been updated: 0.97608 --> 0.97625
# [Evaluate] best accuracy performence has been updated: 0.97625 --> 0.97667
# [Evaluate] best accuracy performence has been updated: 0.97667 --> 0.97733
# [Evaluate] best accuracy performence has been updated: 0.97733 --> 0.97767
# [Evaluate] best accuracy performence has been updated: 0.97767 --> 0.97792
# [Evaluate] best accuracy performence has been updated: 0.97792 --> 0.97792
# [Evaluate] best accuracy performence has been updated: 0.97792 --> 0.97800
# [Train] epoch: 3/100, loss: 0.0838131308555603, score: 0.9708333333333333
# [Evaluate] best accuracy performence has been updated: 0.97800 --> 0.97950
# [Evaluate] best accuracy performence has been updated: 0.97950 --> 0.97975
# [Evaluate] best accuracy performence has been updated: 0.97975 --> 0.98017
# [Evaluate] best accuracy performence has been updated: 0.98017 --> 0.98025
# [Evaluate] best accuracy performence has been updated: 0.98025 --> 0.98058
# [Train] epoch: 4/100, loss: 0.06960535794496536, score: 0.9752916666666667
# [Evaluate] best accuracy performence has been updated: 0.98058 --> 0.98058
# [Evaluate] best accuracy performence has been updated: 0.98058 --> 0.98108
# [Evaluate] best accuracy performence has been updated: 0.98108 --> 0.98133
score: 1.0
# [Evaluate] best accuracy performence has been updated: 0.99417 --> 0.99425
# [Train] epoch: 75/100, loss: 6.331560598482611e-06, score: 1.0
# [Train] epoch: 76/100, loss: 6.2198810155678075e-06, score: 1.0
# [Train] epoch: 77/100, loss: 6.114751158747822e-06, score: 1.0
# [Train] epoch: 78/100, loss: 6.0111678976682015e-06, score: 1.0
# [Train] epoch: 79/100, loss: 5.908710136282025e-06, score: 1.0
# [Train] epoch: 80/100, loss: 5.812895778944949e-06, score: 1.0
# [Evaluate] best accuracy performence has been updated: 0.99425 --> 0.99433
# [Train] epoch: 81/100, loss: 5.723021786252502e-06, score: 1.0
# [Train] epoch: 82/100, loss: 5.630339273920981e-06, score: 1.0
# [Train] epoch: 83/100, loss: 5.544044142880011e-06, score: 1.0
# [Train] epoch: 84/100, loss: 5.456502094602911e-06, score: 1.0
# [Train] epoch: 85/100, loss: 5.379050890041981e-06, score: 1.0
# [Train] epoch: 86/100, loss: 5.295522441883804e-06, score: 1.0
# [Train] epoch: 87/100, loss: 5.216697900323197e-06, score: 1.0
# [Train] epoch: 88/100, loss: 5.141814654052723e-06, score: 1.0
# [Train] epoch: 89/100, loss: 5.070278803032124e-06, score: 1.0
# [Train] epoch: 90/100, loss: 4.997084488422843e-06, score: 1.0
# [Train] epoch: 91/100, loss: 4.927066584059503e-06, score: 1.0
# [Train] epoch: 92/100, loss: 4.859541604673723e-06, score: 1.0
# [Train] epoch: 93/100, loss: 4.7958342292986345e-06, score: 1.0
# [Train] epoch: 94/100, loss: 4.729459760710597e-06, score: 1.0
# [Train] epoch: 95/100, loss: 4.6693457989022136e-06, score: 1.0
# [Train] epoch: 96/100, loss: 4.607803930412047e-06, score: 1.0
# [Train] epoch: 97/100, loss: 4.547409844235517e-06, score: 1.0
# [Train] epoch: 98/100, loss: 4.489359525905456e-06, score: 1.0
# [Train] epoch: 99/100, loss: 4.434006768860854e-06, score: 1.0
# [Train] epoch: 100/100, loss: 4.379116035124753e-06, score: 1.0
# [Test] accuravy/loss: 0.8286/2.3910

# %% [markdown]
# ## 4. Conclusion (5 points)

# %% [markdown]
# 在本次试验中，我们不用自动求导的架构，全部自己实现数据处理、构建模型、损失函数、优化器，并自己实现反向传播，使用了KNN，Softmax回归，前馈神经网络三种方法，探究了一个基于Fashion-MNIST数据集的子集上的图像分类任务。
#
# 最后在使用各种方法（Kaiming He初始化 + SMOTE过采样 + 五层MLP(ReLU) + Momentum优化器 + Dropout层 + 随机小批量梯度下降），在测试集上准确率可以达到82.86%左右。（不同电脑不同随机数造成的初始化结果不同，可能结果有所差异）
#
# 但整体上，每使用一种方法，都会使得结果变得更好。虽然我的结果肯定不是SOTA，但是我很开心，能够一点点尝试不同方法，看着结果一点点进步！
#
#
#
# #### 探索
#
# 在完成基本任务后，我还进行了如下探索：
#
# 1. 使用Xavier 和 Kaiming He 对Linear层的初始化
# 2. 对图像数据的standard normalization 归一化
# 3. 使用小批度随机梯度下降法
# 4. 使用带有Momentum的优化器
# 5. 尝试更多层的前馈神经网络架构 如经典的5层MLP(在MNIST数据集上准确率可达97%)
# 6. 使用SMOTE等过采样算法解决类别不均衡问题
# 7. 尝试ReLU与sigmoid激活函数对模型的不同影响
# 8. 尝试在多层前馈神经网络中使用Dropout层。
#
#
#
#
# #### 问题解决
#
# 本实验中，遇到过超级多的问题，并逐一解决优化，记录部分思考过程如下：
#
# 1. KNN算法写错，准确率一开始只有10%
# 2. softmax回归中，softmax层的计算，换了写法，解决了可能的溢出问题
# 3. softmax回归中的交叉熵损失函数，计算loss，原版paddle书是用循环写的，整批梯度下降则巨慢无比(60000次迭代)，我改成了矩阵写法。
# 4. softmax回归的交叉熵损失函数是独立写的，并没有接上softmax层，这种写法有时候会造成了log(0.0)导致最后和label的0相乘造成nan的情况。我使用了在预测数值上加 1e-10这种极小数字的方法解决了问题。
# 5. 前馈神经网络中，在一般的框架下，最后一层的交叉熵损失函数是包含了softmax层的，又称softmax_crossentropy,经过查阅资料得知（见Reference）,此方法有两个优点：首先是能够用一些方法避免溢出，其次是其求导最后形式极其简洁！我曾经用循环自己实现了一个，是对的，但是巨慢，后来加以改进
# 6. ReLU层的反向传播一开始写错了，造成了很大困扰，最后得以修改。
# 7. 一开始训练非常非常慢！我就用time.perf_counter()给每个部分计时，看看到底是哪里慢了，前馈？反馈？交叉熵损失计算？最后发现慢的地方都写了循环。全改成了矩阵运算！这是拿空间去换时间，代价是，跑着跑着自己电脑内存不够。。。没事，用飞浆平台！感谢百度！
#
#
#
#
# #### 仍有待探索的问题
#
# 限制我的模型的主要问题有两个：
#
# 1. 是数据集的问题，数据集的类别不均衡问题非常严重！长尾效应显著。
#
# 就算使用SMOTE算法过采样，也很难得到很好的效果。就算我划分了验证集，问题在于，验证集来源于训练集，而训练集和测试集的分布明显是不一样的！
#
# 我当然想下载完整Fashipn-MNIST数据集pretrain一下，但我没有（doge）！
#
# 当下CV关于类别不均衡的SOTA方法是什么？
#
# 2. 是网络结构的问题，毕竟是最基础的前馈神经网络，做CV有更加适合的卷积神经网络，更适合提取图像各类局部性特征，而不是建立“全连接”的关系。本次实验是要求Fully Connected Network， 故没有用卷积。
#
# 之前倒是在MNIST数据集上有过尝试，10轮epoch后准确率，FNN可以达到97%，两层卷积达到98%，简易GoogleNet（Inception）达到接近99%， Residual Net达到99%以上。
#
# 以后会用卷积网络做做尝试。
#
#
#
#
# #### 收获
#
# 通过本次实验，把前馈神经网络好好搞了一遍，从底层一点点实现，也使用了诸多的trick,遇到了无数多的bug，消耗了很多时间，但是收获真的很大。
#
# 一点点使用不同方法，一点点看着模型进步。
#
#
#
#
# #### 感谢
#
# 感谢邱锡鹏老师的教授，感谢李鹏助教在此次作业中对我的帮助！

# %% [markdown]
# ## Reference
# List your references here.

# %% [markdown]
# [1] Fashion-MNIST: a Novel Image Dataset for Benchmarking Machine Learning Algorithms. Han Xiao, Kashif Rasul, Roland Vollgraf. arXiv: https://arxiv.org/abs/1708.07747, GitHub: https://github.com/zalandoresearch/fashion-mnist
#
# [2] 解决softmax交叉熵损失的溢出问题的方法 https://blog.csdn.net/muyuu/article/details/122757470
#
# [3] softmax交叉熵损失函数的求导 https://blog.csdn.net/xiaocong1990/article/details/82464069/
#
# [4] https://blog.csdn.net/mch2869253130/article/details/119809360
#
# [5] https://blog.csdn.net/weixin_44042453/article/details/126215890
#
# [6] https://imbalanced-learn.org/stable/over_sampling.html
